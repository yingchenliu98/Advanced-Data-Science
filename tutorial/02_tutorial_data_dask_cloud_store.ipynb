# %% [markdown]
# <h1 style="padding-top: 25px;padding-bottom: 25px;text-align: left; padding-left: 10px; background-color: #DDDDDD;
#     color: black;"> <img style="float: left; padding-right: 10px;" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png" height="50px"> <a href='https://harvard-iacs.github.io/2021-AC215/' target='_blank'><strong><font color="#A41034">AC215: Advanced Practical Data Science, MLOps</font></strong></a></h1>
#
# # **<font color="#A41034">Tutorial 2 - Dask & Cloud Storage</font>**
#
# **Harvard University**<br/>
# **Fall 2021**<br/>
# **Instructor:**<br/>
# Pavlos Protopapas
#
# <hr style="height:2pt">

# %% [markdown]
# ## **<font color="#A41034">Tutorial Outline</font>**

# %% [markdown]
# ## **Learning Objectives**
#
# By the end of this notebook, you should be able to:
# * Familarize with Dask API
# * Use Dask to compute dataset metrics
#
#
# ## **Tutorial Content**
#
# - Download & preview data
# - Introduction to Dask
# - Visualizing DAGs
# - Compute dataset metrics

# %% [markdown]
# ## **<font color="#A41034">Setup Notebook</font>**

# %% [markdown]
# **Copy & setup Colab**

# %% [markdown]
# 1) Select "File" menu and pick "Save a copy in Drive"

# %% [markdown]
# **Installs**

# %%
# !pip install dask dask[dataframe] dask-image
# Out:
# Requirement already satisfied: dask in /usr/local/lib/python3.7/dist-packages (2.12.0)
# Collecting dask-image
#   Downloading dask-image-0.6.0.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 1.5 MB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from dask-image) (1.19.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from dask-image) (1.4.1)
# Collecting pims>=0.4.1
#   Downloading PIMS-0.5.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 3.2 MB/s
# Requirement already satisfied: toolz>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from dask) (0.11.1)
# Collecting slicerator>=0.9.8
#   Downloading slicerator-1.0.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: six>=1.8 in /usr/local/lib/python3.7/dist-packages (from pims>=0.4.1->dask-image) (1.15.0)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from dask) (1.1.5)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2021.8.1-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 37.0 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.0->dask) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.0->dask) (2018.9)
# Collecting locket
#   Downloading locket-0.2.1-py2.py3-none-any.whl (4.1 kB)
# Building wheels for collected packages: dask-image, pims
#   Building wheel for dask-image (setup.py) ... done
#   Created wheel for dask-image: filename=dask_image-0.6.0-py2.py3-none-any.whl size=37243 sha256=342b89630c4c4d0671165d0b7eb37d5ce70b96e2abf895ea7d7b9bb7bd9e34ea
#   Stored in directory: /root/.cache/pip/wheels/d5/0a/44/cb03cf4230cc2c138ac44792a6d43fa836fb6e85ddc0836f5e
#   Building wheel for pims (setup.py) ... done
#   Created wheel for pims: filename=PIMS-0.5-py3-none-any.whl size=84326 sha256=dee652c044329e1203802420f5bb8245fba5a8a6f060cf49d26d3e61d9e30b30
#   Stored in directory: /root/.cache/pip/wheels/75/02/a9/86571c38081ba4c1832eb95430b5d588dfa15a738e2a603737
# Successfully built dask-image pims
# Installing collected packages: slicerator, locket, pims, partd, fsspec, dask-image
# Successfully installed dask-image-0.6.0 fsspec-2021.8.1 locket-0.2.1 partd-1.2.0 pims-0.5 slicerator-1.0.0

# %% [markdown]
# **Imports**

# %%
import os
import requests
import zipfile
import tarfile
import shutil
import math
import json
import time
import sys
import cv2
import string
import re
import subprocess
import hashlib
import numpy as np
import pandas as pd
from glob import glob
import collections
import unicodedata
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# Tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.utils.layer_utils import count_params

# sklearn
from sklearn.model_selection import train_test_split

# Dask
import dask
import dask.dataframe as dd
import dask.delayed as delayed
from dask.diagnostics import ProgressBar

# Colab auth
from google.colab import auth
from google.cloud import storage

# %% [markdown]
# **Verify Setup**

# %%
# Enable/Disable Eager Execution
# Reference: https://www.tensorflow.org/guide/eager
# TensorFlow's eager execution is an imperative programming environment that evaluates operations immediately, 
# without building graphs

#tf.compat.v1.disable_eager_execution()
#tf.compat.v1.enable_eager_execution()

print("tensorflow version", tf.__version__)
print("keras version", tf.keras.__version__)
print("Eager Execution Enabled:", tf.executing_eagerly())

# Get the number of replicas 
strategy = tf.distribute.MirroredStrategy()
print("Number of replicas:", strategy.num_replicas_in_sync)

devices = tf.config.experimental.get_visible_devices()
print("Devices:", devices)
print(tf.config.experimental.list_logical_devices('GPU'))

print("GPU Available: ", tf.config.list_physical_devices('GPU'))
print("All Physical Devices", tf.config.list_physical_devices())

# Better performance with the tf.data API
# Reference: https://www.tensorflow.org/guide/data_performance
AUTOTUNE = tf.data.experimental.AUTOTUNE
# Out:
# tensorflow version 2.6.0
# keras version 2.6.0
# Eager Execution Enabled: True
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# Number of replicas: 1
# Devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# []
# GPU Available:  []
# All Physical Devices [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# **Utils**

# %% [markdown]
# Here are some util functions that we will be using for this lab

# %%
def download_file(packet_url, base_path="", extract=False, headers=None):
  if base_path != "":
    if not os.path.exists(base_path):
      os.mkdir(base_path)
  packet_file = os.path.basename(packet_url)
  with requests.get(packet_url, stream=True, headers=headers) as r:
      r.raise_for_status()
      with open(os.path.join(base_path,packet_file), 'wb') as f:
          for chunk in r.iter_content(chunk_size=8192):
              f.write(chunk)
  
  if extract:
    if packet_file.endswith(".zip"):
      with zipfile.ZipFile(os.path.join(base_path,packet_file)) as zfile:
        zfile.extractall(base_path)
    else:
      packet_name = packet_file.split('.')[0]
      with tarfile.open(os.path.join(base_path,packet_file)) as tfile:
        tfile.extractall(base_path)

class JsonEncoder(json.JSONEncoder):
  def default(self, obj):
    if isinstance(obj, np.integer):
        return int(obj)
    elif isinstance(obj, np.floating):
        return float(obj)
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    else:
        return super(JsonEncoder, self).default(obj)

# %% [markdown]
# ## **<font color="#A41034">Dataset</font>**

# %% [markdown]
# #### **Download**

# %%
start_time = time.time()
download_file("https://github.com/dlops-io/datasets/releases/download/v1.0/mushrooms_3_labels.zip", base_path="datasets", extract=True)
download_file("https://github.com/dlops-io/datasets/releases/download/v1.0/Parking_Violations_Issued_-_Fiscal_Year_2017.csv.zip", 
              base_path="datasets", extract=True)
execution_time = (time.time() - start_time)/60.0
print("Download execution time (mins)",execution_time)
# Out:
# Download execution time (mins) 1.185491391023

# %% [markdown]
# ## **<font color="#A41034">Introduction to Dask</font>**

# %% [markdown]
# ### **Load Data**
#
# Read data into a dataframe using dask API

# %%
parking_violation_csv = os.path.join("datasets","Parking_Violations_Issued_-_Fiscal_Year_2017.csv")

# read data using DataFrame API
df = dd.read_csv(parking_violation_csv) # , blocksize=640000000)

print("Shape:", df.shape)
df
# Out:
# Shape: (Delayed('int-ec1233a3-c2e6-400b-8aba-eef5ac0c9f4e'), 43)
# Dask DataFrame Structure:
#                Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# npartitions=33
#                         int64   object             object     object     object          int64            object       object         object        int64        int64        int64                   int64            float64              int64           int64       int64         object       object         object              object           object                            object       object      object              object               int64       int64       object               object                     object               object             object        object               float64        int64       object          int64              object                object                           float64           float64                  float64
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# ...                       ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# Dask Name: from-delayed, 99 tasks

# %%
#df.visualize()

# %% [markdown]
# **note that**
# - _metadata_ are shown in the frame instead of data sample
# - _syntax_ is pretty similar to Pandas API
# - _# partitions_  is the number of splits used to separate the main dataset. The optimal number is decided by the scheduler that split Pandas DataFrame into smaller chuncks. In this case each partitions is ~64MB (i.e. Dataset size/npartitions = 2GB/33). If we have one worker, Dask will cycle to each partition one at time.
# - _data types_ are reported under each column name (similary to describe method in Pandas, however performed through random sampling because data scattered across multiple physical machines). Good practice is to explicit data types instead relying on Dask's inference (store in binary format ideally, see links to Write and Read Parquet).
# - _Dask Name_ reports the name of the DAG (i.e. from-delayed)
# - _# tasks_ is the number of nodes in the DAG. You can think of a task as a Python function and in this case each partition operates 3 tasks: 1) reading the raw data, 2) splitting the data in appropriate blocks and, 3) initialazing the DataFrame object. Every task comes with some overhead (between 200μs and 1ms).
#
# <img src="https://storage.googleapis.com/public_colab_images/ai5/dask_partitions.PNG" width="600">
# <br>
#
# Partition process from **Data Science with Python and Dask**
#
# **Want to know more?**
# - [Best Practices](https://docs.dask.org/en/latest/best-practices.html)
# - [Write and Read Parquet](https://examples.dask.org/dataframes/01-data-access.html)

# %% [markdown]
# Next lets display some data in the dataframe

# %%
# Display the top rows
df.head()
# Out:
#    Summons Number Plate ID  ... Hydrant Violation Double Parking Violation
# 0      5092469481  GZH7067  ...               NaN                      NaN
# 1      5092451658  GZH7067  ...               NaN                      NaN
# 2      4006265037  FZX9232  ...               NaN                      NaN
# 3      8478629828  66623ME  ...               NaN                      NaN
# 4      7868300310  37033JV  ...               NaN                      NaN
#
# [5 rows x 43 columns]

# %% [markdown]
# ### **Check data quality issues**

# %%
# count missing values
missing_values = df.isnull().sum()
missing_values
# Out:
# Dask Series Structure:
# npartitions=1
# Date First Observed    int64
# Violation Time           ...
# dtype: int64
# Dask Name: dataframe-sum-agg, 166 tasks

# %%
#missing_values.visualize()

# %% [markdown]
# **note that**
# - _dask object_ created is a series containing _metadata_ and _syntax_ is pretty similar to Pandas API
# - _processing hasn't be completed_ yet, instead Dask prepared a DAG stored in the missing values variable (advantage of building graph quickly without need to wait for computation)
# - _# tasks_ increased because have been added 2 tasks (i.e. check missing values and sum) for each of the 33 partitions as well as a final addition to aggregate the results among all the partitions for a total of 166 = [(66+1)+99]

# %%
# calculate percent missing values
df_size =  df.index.size 
missing_count = ((missing_values /df_size)*100)
missing_count
# Out:
# Dask Series Structure:
# npartitions=1
# Date First Observed    float64
# Violation Time             ...
# dtype: float64
# Dask Name: mul, 235 tasks

# %%
#missing_count.visualize()

# %% [markdown]
# **note that**
#
# - _dask object_ created is a series and computation hasn't be completed yet
# - _df.index.size_ is a dask object _dask.dataframe.core.Scalar_ . You cannot access its value/lenght directely like you would do with a list (e.g. len()). It would go against the whole idea of dask (i.e. read all the dataset)
# - _# tasks_ increased because we have  added: 2 tasks per partition (2*33) for the index() plus one aggregation and  2 tasks (i.e. division and multiplication).
# 166+67+2 = 235
# - _data type_ has changed from int64 to float64. Dask automatically converted it once the datatype at the output might not match the input after the division

# %%
# run computations using compute method
with ProgressBar():
    missing_count_percent = missing_count.compute()
missing_count_percent
# Out:
# [###################################     ] | 89% Completed |  1min 11.5s
# /usr/local/lib/python3.7/dist-packages/dask/core.py:121: DtypeWarning: Columns (18,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   return func(*(_execute_task(a, cache) for a in args))
# [########################################] | 100% Completed |  1min 13.9s
# Summons Number                         0.000000
# Plate ID                               0.006739
# Registration State                     0.000000
# Plate Type                             0.000000
# Issue Date                             0.000000
# Violation Code                         0.000000
# Vehicle Body Type                      0.395361
# Vehicle Make                           0.676199
# Issuing Agency                         0.000000
# Street Code1                           0.000000
# Street Code2                           0.000000
# Street Code3                           0.000000
# Vehicle Expiration Date                0.000000
# Violation Location                    19.183510
# Violation Precinct                     0.000000
# Issuer Precinct                        0.000000
# Issuer Code                            0.000000
# Issuer Command                        19.093212
# Issuer Squad                          19.101506
# Violation Time                         0.000583
# Time First Observed                   92.217488
# Violation County                       0.366073
# Violation In Front Of Or Opposite     20.005826
# House Number                          21.184968
# Street Name                            0.037110
# Intersecting Street                   68.827675
# Date First Observed                    0.000000
# Law Section                            0.000000
# Sub Division                           0.007155
# Violation Legal Code                  80.906214
# Days Parking In Effect                25.107923
# From Hours In Effect                  50.457575
# To Hours In Effect                    50.457548
# Vehicle Color                          1.410179
# Unregistered Vehicle?                 89.562223
# Vehicle Year                           0.000000
# Meter Number                          83.472476
# Feet From Curb                         0.000000
# Violation Post Code                   29.530489
# Violation Description                 10.436611
# No Standing or Stopping Violation    100.000000
# Hydrant Violation                    100.000000
# Double Parking Violation             100.000000
# dtype: float64

# %%
# run computations using compute method
missing_count_percent = missing_count.compute()
missing_count_percent
# Out:
# /usr/local/lib/python3.7/dist-packages/dask/core.py:121: DtypeWarning: Columns (18,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   return func(*(_execute_task(a, cache) for a in args))
# Summons Number                         0.000000
# Plate ID                               0.006739
# Registration State                     0.000000
# Plate Type                             0.000000
# Issue Date                             0.000000
# Violation Code                         0.000000
# Vehicle Body Type                      0.395361
# Vehicle Make                           0.676199
# Issuing Agency                         0.000000
# Street Code1                           0.000000
# Street Code2                           0.000000
# Street Code3                           0.000000
# Vehicle Expiration Date                0.000000
# Violation Location                    19.183510
# Violation Precinct                     0.000000
# Issuer Precinct                        0.000000
# Issuer Code                            0.000000
# Issuer Command                        19.093212
# Issuer Squad                          19.101506
# Violation Time                         0.000583
# Time First Observed                   92.217488
# Violation County                       0.366073
# Violation In Front Of Or Opposite     20.005826
# House Number                          21.184968
# Street Name                            0.037110
# Intersecting Street                   68.827675
# Date First Observed                    0.000000
# Law Section                            0.000000
# Sub Division                           0.007155
# Violation Legal Code                  80.906214
# Days Parking In Effect                25.107923
# From Hours In Effect                  50.457575
# To Hours In Effect                    50.457548
# Vehicle Color                          1.410179
# Unregistered Vehicle?                 89.562223
# Vehicle Year                           0.000000
# Meter Number                          83.472476
# Feet From Curb                         0.000000
# Violation Post Code                   29.530489
# Violation Description                 10.436611
# No Standing or Stopping Violation    100.000000
# Hydrant Violation                    100.000000
# Double Parking Violation             100.000000
# dtype: float64

# %%
type(missing_count_percent)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **note that**
#
# - _.compute() method_ is necessary to run the actions embedded in each node of the DAG
# - The _results_ of the compute method are stored into a Pandas Series
# - _ProgressBar()_ is a wrapper to keep track of running tasks. It shows completed work
# - _from a quick visual inspection_ we can see that are columns that are incomplete and we should drop

# %% [markdown]
# ### **Drop Columns**

# %%
# filter sparse columns(greater than 60% missing values) and store them
columns_to_drop = missing_count_percent[missing_count_percent > 60].index
columns_to_drop
# Out:
# Index(['Time First Observed', 'Intersecting Street', 'Violation Legal Code',
#        'Unregistered Vehicle?', 'Meter Number',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation'],
#       dtype='object')

# %%
# drop sparse columns
with ProgressBar():
  df_dropped = df.drop(columns_to_drop.to_list(), axis=1).compute()
# Out:
# [#####################################   ] | 93% Completed |  1min  4.8s
# /usr/local/lib/python3.7/dist-packages/dask/core.py:121: DtypeWarning: Columns (18,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   return func(*(_execute_task(a, cache) for a in args))
# [########################################] | 100% Completed |  1min  6.0s

# %% [markdown]
# **note that**
#
# - _use Pandas Series_ to drop columns in Dask DataFrames because each partition is a Pandas DataFrame
# - In the case the Series is made available to all threads, in a cluster it would be serialized and brodcast to all the worker nodes
# - _.persit() method_ allows to store in memory intermediate computations so they can be reused.

# %% [markdown]
# ## **<font color="#A41034">Visualizing DAGs</font>**

# %% [markdown]
# ### **DAG with one node with dependency**

# %%
def increment(i):
    return i + 1

def add(x, y):
    return x + y

# wrap functions within delayed object and chain
x = delayed(increment)(1)
y = delayed(increment)(2)
z = delayed(add)(x, y)

print("z",z, "x",x,"y",y)
# visualize the DAG
z.visualize()
# Out:
# z Delayed('add-9f5847fd-3f13-4d33-b29d-2718cd022452') x Delayed('increment-bccff077-3628-4bba-938b-fe660d064917') y Delayed('increment-d98b88c9-2d68-4832-9c1b-830c8bd619d3')

# %%
def increment(i):
    return i + 1

def add(x, y):
    return x + y

x = increment(1)
y = increment(2)
z = delayed(add)(x, y)
#z = add(x, y)
print("z",z, "x",x,"y",y)
# Out:
# z Delayed('add-d6038ec4-d690-4093-95f5-39ee9edb914a') x 2 y 3

# %%
z.visualize()

# %%
# show the result
z.compute()
# Out:
# 5

# %%
@dask.delayed
def increment(i):
    return i + 1

@dask.delayed
def add(x, y):
    return x + y



x = increment(1)
y = increment(2)
#z = delayed(add)(x, y)
z = add(x, y)
z.visualize()

# %%
dask.compute(add(increment(1),increment(2)))
# Out:
# (5,)

# %% [markdown]
# **note that**
# - _to build a node_ wrap the function with the delayed object and then pass the arguments of the function. You could also use a decoretors (see example).
# - _circles_ symbolize function and computations while _squares_ intermediate or final result
# - _incoming arrows_ represent dependecies. The _increment_ function do not have any dependency while _add_ function has two. Thus, add function has to wait until objects x and y have been calculated
# - functions without dependencies can be computed independentely and a worker can be assigned to each one of them
# - _use method .visualize()_ on the last node with dependencies to peak at the DAG
# - _Dask does not compute the DAG_ . Use the method .compute() on the last node to see the result

# %% [markdown]
# ### **DAG with more than one node with dependencies**
#
# - we are going to build a more complex DAG with two layers:
#     - layer1 is built by looping over a list of data using a list comprehension to create dask delayed objects as "leaves" node. This layer combines the previously created function increment with the values in the list, then use the built in function sum to combine the results;
#     - layer2 is built looping on each object created in layer1 and

# %%
data = [1, 2, 3, 4, 5]

# compile first layer and visualize
layer1 = [delayed(increment)(i) for i in data]
total1 = delayed(sum)(layer1)
total1.visualize()

# %%
layer1 = [ increment(i) for i in data]
layer2 = sum(layer1)
layer2
# Out:
# Delayed('add-1531f242a3c8807278fe5dbcc2130792')

# %%
def double(x):
    return x * 2

# compile second layer and visualize
layer2 = [delayed(double)(j) for j in layer1]
total2 = delayed(sum)(layer2)#.persist()
total2.visualize()

# %%
z = total2.compute()
#z = total2
z
# Out:
# 40

# %% [markdown]
# **note that**
# - _built in function_
# - _persistent_ using .persist() and it will be represented as a rectangle in the graph

# %% [markdown]
# ## **<font color="#A41034">Example: Build Dask DataFrame</font>**

# %% [markdown]
# Let us build a Dask DataFrame from a Pandas DataFrame

# %%
# create lists of actions
action_IDs = [i for i in range(0,10)]
action_description = ['Clean dish', 'Dress up', 'Wash clothes','Take shower',
                      'Groceries','Take shower','Dress up','Gym','Take shower','Movie']
action_date = ['2021-8-16', '2021-8-16', '2021-8-16', '2021-8-16', '2021-8-16', 
               '2021-8-17', '2021-8-17', '2021-8-17', '2021-8-17', '2021-8-17']

# store list into Pandas DataFrame
action_pandas_df = pd.DataFrame({'Action ID': action_IDs, 
                                 'Action Description': action_description, 
                                 'Date': action_date},
                                 columns=['Action ID', 'Action Description', 'Date'])
action_pandas_df
# Out:
#    Action ID Action Description       Date
# 0          0         Clean dish  2021-8-16
# 1          1           Dress up  2021-8-16
# 2          2       Wash clothes  2021-8-16
# 3          3        Take shower  2021-8-16
# 4          4          Groceries  2021-8-16
# 5          5        Take shower  2021-8-17
# 6          6           Dress up  2021-8-17
# 7          7                Gym  2021-8-17
# 8          8        Take shower  2021-8-17
# 9          9              Movie  2021-8-17

# %%
# convert Pandas DataFrame to a Dask DataFrame
action_dask_df = dd.from_pandas(action_pandas_df, npartitions=3)

# %%
action_dask_df
# Out:
# Dask DataFrame Structure:
#               Action ID Action Description    Date
# npartitions=3
# 0                 int64             object  object
# 4                   ...                ...     ...
# 8                   ...                ...     ...
# 9                   ...                ...     ...
# Dask Name: from_pandas, 3 tasks

# %%
action_dask_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/dask/dataframe/core.py:5970: UserWarning: Insufficient elements for `head`. 5 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
#    Action ID Action Description       Date
# 0          0         Clean dish  2021-8-16
# 1          1           Dress up  2021-8-16
# 2          2       Wash clothes  2021-8-16
# 3          3        Take shower  2021-8-16

# %%
# info Dask Dataframe
print('<index where df has been split>', action_dask_df.divisions)
print('<# partitions>', action_dask_df.npartitions)
# Out:
# <index where df has been split> (0, 4, 8, 9)
# <# partitions> 3

# %%
# count rows per partition
count_perpartition = action_dask_df.map_partitions(len)
count_perpartition
# Out:
# Dask Series Structure:
# npartitions=3
# 0    int64
# 4      ...
# 8      ...
# 9      ...
# dtype: int64
# Dask Name: len, 6 tasks

# %%
count_perpartition.visualize()

# %%
count_perpartition.compute()
# Out:
# 0    4
# 1    4
# 2    2
# dtype: int64

# %%
# filter entries in dask dataframe
print('\n <number of entries in each partition after filtering>')
action_filtered = action_dask_df[action_dask_df['Action Description'] != 'Take shower']
print(action_filtered.map_partitions(len).compute())

print('\n <double check number of entries after reorganizing dataframe in one partition>')
action_filtered_reduced = action_filtered.repartition(npartitions=1)
print(action_filtered_reduced.map_partitions(len).compute())
# Out:
#  <number of entries in each partition after filtering>
# 0    3
# 1    3
# 2    1
# dtype: int64
#
#  <double check number of entries after reorganizing dataframe in one partition>
# 0    7
# dtype: int64

# %% [markdown]
# ## **<font color="#A41034">Compute Mushroom dataset metrics</font>**

# %% [markdown]
# #### Load image file paths

# %%
mushrooms_data_path = os.path.join("datasets","mushrooms","**/*")

# Get a list of paths to all images
image_files = glob(mushrooms_data_path)
print("Number of file:",len(image_files))
# Out:
# Number of file: 1643

# %% [markdown]
# #### Compute Metrics using Dask

# %%
image_width = 224
image_height = 224
num_channels = 3

@dask.delayed
def read_resize_image(file_path):
  # read image
  image = cv2.imread(file_path)
  # convert to rgb
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  # Resize image
  image = cv2.resize(image, (image_width,image_height), interpolation = cv2.INTER_AREA)

  return image

# %%
lazy_loaded_images = [read_resize_image(path) for path in image_files]

image_arrays = [dask.array.from_delayed(img,dtype=np.uint8,shape=(image_height, image_width, num_channels)) for img in lazy_loaded_images]
all_images_dask = dask.array.stack(image_arrays, axis=0)

# %%
lazy_loaded_images[0:2]
# Out:
# [Delayed('read_resize_image-8723f25f-8789-44f4-beda-93651ff3d993'),
#  Delayed('read_resize_image-eb2bb918-ab16-4eb6-a2df-a70cfd387d9c')]

# %%
all_images_dask
# Out:
# dask.array<stack, shape=(1643, 224, 224, 3), dtype=uint8, chunksize=(1, 224, 224, 3), chunktype=numpy.ndarray>

# %%
start_time = time.time()
dask_metrics = {}
#mean = all_images_dask.mean(axis=(0,1, 2)).compute()
#stdev = all_images_dask.std(axis=(0,1, 2)).compute()
mean, stdev = dask.compute(all_images_dask.mean(axis=(0,1, 2)), all_images_dask.std(axis=(0,1, 2)))
print("mean:", mean)
print("stdev:", stdev)
dask_metrics["mean"] = mean
dask_metrics["stdev"] = stdev
execution_time = (time.time() - start_time)/60.0
print("Execution time (mins)",execution_time)
# Out:
# mean: [146.99367095 132.88599115 115.4490384 ]
# stdev: [77.33130099 76.97771813 82.08600301]
# Execution time (mins) 0.7174902955691019

# %% [markdown]
# #### Compute Metrics using Numpy
#
# Using numpy we load all the images and compute the dataset metrics. This only owrks if we can load all images into memory. Since our dataset is small this is possible

# %%
all_images_numpy = []

start_time = time.time()
for file_path in image_files:
  print(file_path)
  # read image
  image = cv2.imread(file_path)
  # convert to rgb
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  # Resize image
  image = cv2.resize(image, (image_width,image_height), interpolation = cv2.INTER_AREA)
  # Train x
  all_images_numpy.append(image)

# Convert to numpy array
all_images_numpy = np.asarray(all_images_numpy)
numpy_metrics = {}
mean = np.mean(all_images_numpy, axis=(0,1, 2))
print("mean:", mean)
stdev = np.std(all_images_numpy, axis=(0,1, 2))
print("stdev:", stdev)
numpy_metrics["mean"] = mean
numpy_metrics["stdev"] = stdev
execution_time = (time.time() - start_time)/60.0
print("Execution time (mins)",execution_time)
# Out:
# datasets/mushrooms/oyster/401.jpg
# datasets/mushrooms/oyster/226.jpg
# datasets/mushrooms/oyster/428.jpg
# datasets/mushrooms/oyster/261.jpg
# datasets/mushrooms/oyster/412.jpg
# datasets/mushrooms/oyster/508.jpg
# datasets/mushrooms/oyster/41.jpg
# datasets/mushrooms/oyster/124.jpg
# datasets/mushrooms/oyster/553.jpg
# datasets/mushrooms/oyster/210.jpg
# datasets/mushrooms/oyster/381.jpg
# datasets/mushrooms/oyster/596.jpg
# datasets/mushrooms/oyster/17.jpg
# datasets/mushrooms/oyster/38.jpg
# datasets/mushrooms/oyster/79.jpg
# datasets/mushrooms/oyster/456.jpg
# datasets/mushrooms/oyster/274.jpg
# datasets/mushrooms/oyster/264.jpg
# datasets/mushrooms/oyster/7.jpg
# datasets/mushrooms/oyster/461.jpg
# datasets/mushrooms/oyster/337.jpg
# datasets/mushrooms/oyster/101.jpg
# datasets/mushrooms/oyster/20.jpg
# datasets/mushrooms/oyster/457.jpg
# datasets/mushrooms/oyster/119.jpg
# datasets/mushrooms/oyster/328.jpg
# datasets/mushrooms/oyster/440.jpg
# datasets/mushrooms/oyster/575.jpg
# datasets/mushrooms/oyster/431.jpg
# datasets/mushrooms/oyster/50.jpg
# datasets/mushrooms/oyster/71.jpg
# datasets/mushrooms/oyster/15.jpg
# datasets/mushrooms/oyster/489.jpg
# datasets/mushrooms/oyster/116.jpg
# datasets/mushrooms/oyster/542.jpg
# datasets/mushrooms/oyster/256.jpg
# datasets/mushrooms/oyster/35.jpg
# datasets/mushrooms/oyster/272.jpg
# datasets/mushrooms/oyster/391.jpg
# datasets/mushrooms/oyster/476.jpg
# datasets/mushrooms/oyster/497.jpg
# datasets/mushrooms/oyster/2.jpg
# datasets/mushrooms/oyster/8.jpg
# datasets/mushrooms/oyster/251.jpg
# datasets/mushrooms/oyster/395.jpg
# datasets/mushrooms/oyster/245.jpg
# datasets/mushrooms/oyster/538.jpg
# datasets/mushrooms/oyster/105.jpg
# datasets/mushrooms/oyster/205.jpg
# datasets/mushrooms/oyster/529.jpg
# datasets/mushrooms/oyster/1.jpg
# datasets/mushrooms/oyster/561.jpg
# datasets/mushrooms/oyster/345.jpg
# datasets/mushrooms/oyster/556.jpg
# datasets/mushrooms/oyster/287.jpg
# datasets/mushrooms/oyster/236.jpg
# datasets/mushrooms/oyster/268.jpg
# datasets/mushrooms/oyster/500.jpg
# datasets/mushrooms/oyster/455.jpg
# datasets/mushrooms/oyster/580.jpg
# datasets/mushrooms/oyster/299.jpg
# datasets/mushrooms/oyster/86.jpg
# datasets/mushrooms/oyster/545.jpg
# datasets/mushrooms/oyster/586.jpg
# datasets/mushrooms/oyster/588.jpg
# datasets/mushrooms/oyster/46.jpg
# datasets/mushrooms/oyster/183.jpg
# datasets/mushrooms/oyster/126.jpg
# datasets/mushrooms/oyster/192.jpg
# datasets/mushrooms/oyster/550.jpg
# datasets/mushrooms/oyster/585.jpg
# datasets/mushrooms/oyster/13.jpg
# datasets/mushrooms/oyster/399.jpg
# datasets/mushrooms/oyster/336.jpg
# datasets/mushrooms/oyster/270.jpg
# datasets/mushrooms/oyster/269.jpg
# datasets/mushrooms/oyster/25.jpg
# datasets/mushrooms/oyster/442.jpg
# datasets/mushrooms/oyster/129.jpg
# datasets/mushrooms/oyster/423.jpg
# datasets/mushrooms/oyster/452.jpg
# datasets/mushrooms/oyster/144.jpg
# datasets/mushrooms/oyster/597.jpg
# datasets/mushrooms/oyster/114.jpg
# datasets/mushrooms/oyster/195.jpg
# datasets/mushrooms/oyster/107.jpg
# datasets/mushrooms/oyster/536.jpg
# datasets/mushrooms/oyster/537.jpg
# datasets/mushrooms/oyster/520.jpg
# datasets/mushrooms/oyster/463.jpg
# datasets/mushrooms/oyster/477.jpg
# datasets/mushrooms/oyster/546.jpg
# datasets/mushrooms/oyster/425.jpg
# datasets/mushrooms/oyster/120.jpg
# datasets/mushrooms/oyster/393.jpg
# datasets/mushrooms/oyster/288.jpg
# datasets/mushrooms/oyster/103.jpg
# datasets/mushrooms/oyster/417.jpg
# datasets/mushrooms/oyster/75.jpg
# datasets/mushrooms/oyster/283.jpg
# datasets/mushrooms/oyster/522.jpg
# datasets/mushrooms/oyster/380.jpg
# datasets/mushrooms/oyster/3.jpg
# datasets/mushrooms/oyster/222.jpg
# datasets/mushrooms/oyster/52.jpg
# datasets/mushrooms/oyster/115.jpg
# datasets/mushrooms/oyster/387.jpg
# datasets/mushrooms/oyster/94.jpg
# datasets/mushrooms/oyster/117.jpg
# datasets/mushrooms/oyster/273.jpg
# datasets/mushrooms/oyster/577.jpg
# datasets/mushrooms/oyster/140.jpg
# datasets/mushrooms/oyster/591.jpg
# datasets/mushrooms/oyster/134.jpg
# datasets/mushrooms/oyster/321.jpg
# datasets/mushrooms/oyster/91.jpg
# datasets/mushrooms/oyster/26.jpg
# datasets/mushrooms/oyster/569.jpg
# datasets/mushrooms/oyster/285.jpg
# datasets/mushrooms/oyster/146.jpg
# datasets/mushrooms/oyster/329.jpg
# datasets/mushrooms/oyster/490.jpg
# datasets/mushrooms/oyster/6.jpg
# datasets/mushrooms/oyster/515.jpg
# datasets/mushrooms/oyster/173.jpg
# datasets/mushrooms/oyster/421.jpg
# datasets/mushrooms/oyster/305.jpg
# datasets/mushrooms/oyster/331.jpg
# datasets/mushrooms/oyster/517.jpg
# datasets/mushrooms/oyster/349.jpg
# datasets/mushrooms/oyster/276.jpg
# datasets/mushrooms/oyster/32.jpg
# datasets/mushrooms/oyster/292.jpg
# datasets/mushrooms/oyster/422.jpg
# datasets/mushrooms/oyster/33.jpg
# datasets/mushrooms/oyster/479.jpg
# datasets/mushrooms/oyster/221.jpg
# datasets/mushrooms/oyster/132.jpg
# datasets/mushrooms/oyster/11.jpg
# datasets/mushrooms/oyster/216.jpg
# datasets/mushrooms/oyster/296.jpg
# datasets/mushrooms/oyster/366.jpg
# datasets/mushrooms/oyster/392.jpg
# datasets/mushrooms/oyster/260.jpg
# datasets/mushrooms/oyster/318.jpg
# datasets/mushrooms/oyster/404.jpg
# datasets/mushrooms/oyster/164.jpg
# datasets/mushrooms/oyster/594.jpg
# datasets/mushrooms/oyster/157.jpg
# datasets/mushrooms/oyster/574.jpg
# datasets/mushrooms/oyster/100.jpg
# datasets/mushrooms/oyster/297.jpg
# datasets/mushrooms/oyster/326.jpg
# datasets/mushrooms/oyster/389.jpg
# datasets/mushrooms/oyster/275.jpg
# datasets/mushrooms/oyster/579.jpg
# datasets/mushrooms/oyster/191.jpg
# datasets/mushrooms/oyster/494.jpg
# datasets/mushrooms/oyster/448.jpg
# datasets/mushrooms/oyster/472.jpg
# datasets/mushrooms/oyster/37.jpg
# datasets/mushrooms/oyster/255.jpg
# datasets/mushrooms/oyster/66.jpg
# datasets/mushrooms/oyster/335.jpg
# datasets/mushrooms/oyster/560.jpg
# datasets/mushrooms/oyster/76.jpg
# datasets/mushrooms/oyster/396.jpg
# datasets/mushrooms/oyster/316.jpg
# datasets/mushrooms/oyster/241.jpg
# datasets/mushrooms/oyster/499.jpg
# datasets/mushrooms/oyster/64.jpg
# datasets/mushrooms/oyster/98.jpg
# datasets/mushrooms/oyster/240.jpg
# datasets/mushrooms/oyster/147.jpg
# datasets/mushrooms/oyster/467.jpg
# datasets/mushrooms/oyster/340.jpg
# datasets/mushrooms/oyster/55.jpg
# datasets/mushrooms/oyster/512.jpg
# datasets/mushrooms/oyster/523.jpg
# datasets/mushrooms/oyster/278.jpg
# datasets/mushrooms/oyster/505.jpg
# datasets/mushrooms/oyster/232.jpg
# datasets/mushrooms/oyster/143.jpg
# datasets/mushrooms/oyster/265.jpg
# datasets/mushrooms/oyster/400.jpg
# datasets/mushrooms/oyster/388.jpg
# datasets/mushrooms/oyster/136.jpg
# datasets/mushrooms/oyster/70.jpg
# datasets/mushrooms/oyster/217.jpg
# datasets/mushrooms/oyster/367.jpg
# datasets/mushrooms/oyster/24.jpg
# datasets/mushrooms/oyster/277.jpg
# datasets/mushrooms/oyster/172.jpg
# datasets/mushrooms/oyster/109.jpg
# datasets/mushrooms/oyster/323.jpg
# datasets/mushrooms/oyster/312.jpg
# datasets/mushrooms/oyster/59.jpg
# datasets/mushrooms/oyster/82.jpg
# datasets/mushrooms/oyster/123.jpg
# datasets/mushrooms/oyster/170.jpg
# datasets/mushrooms/oyster/383.jpg
# datasets/mushrooms/oyster/444.jpg
# datasets/mushrooms/oyster/317.jpg
# datasets/mushrooms/oyster/61.jpg
# datasets/mushrooms/oyster/338.jpg
# datasets/mushrooms/oyster/314.jpg
# datasets/mushrooms/oyster/228.jpg
# datasets/mushrooms/oyster/547.jpg
# datasets/mushrooms/oyster/562.jpg
# datasets/mushrooms/oyster/309.jpg
# datasets/mushrooms/oyster/193.jpg
# datasets/mushrooms/oyster/220.jpg
# datasets/mushrooms/oyster/92.jpg
# datasets/mushrooms/oyster/204.jpg
# datasets/mushrooms/oyster/81.jpg
# datasets/mushrooms/oyster/227.jpg
# datasets/mushrooms/oyster/49.jpg
# datasets/mushrooms/oyster/590.jpg
# datasets/mushrooms/oyster/301.jpg
# datasets/mushrooms/oyster/339.jpg
# datasets/mushrooms/oyster/293.jpg
# datasets/mushrooms/oyster/361.jpg
# datasets/mushrooms/oyster/131.jpg
# datasets/mushrooms/oyster/294.jpg
# datasets/mushrooms/oyster/44.jpg
# datasets/mushrooms/oyster/160.jpg
# datasets/mushrooms/oyster/324.jpg
# datasets/mushrooms/oyster/54.jpg
# datasets/mushrooms/oyster/576.jpg
# datasets/mushrooms/oyster/368.jpg
# datasets/mushrooms/oyster/62.jpg
# datasets/mushrooms/oyster/127.jpg
# datasets/mushrooms/oyster/281.jpg
# datasets/mushrooms/oyster/474.jpg
# datasets/mushrooms/oyster/564.jpg
# datasets/mushrooms/oyster/491.jpg
# datasets/mushrooms/oyster/36.jpg
# datasets/mushrooms/oyster/359.jpg
# datasets/mushrooms/oyster/493.jpg
# datasets/mushrooms/oyster/568.jpg
# datasets/mushrooms/oyster/429.jpg
# datasets/mushrooms/oyster/271.jpg
# datasets/mushrooms/oyster/89.jpg
# datasets/mushrooms/oyster/158.jpg
# datasets/mushrooms/oyster/369.jpg
# datasets/mushrooms/oyster/69.jpg
# datasets/mushrooms/oyster/528.jpg
# datasets/mushrooms/oyster/218.jpg
# datasets/mushrooms/oyster/373.jpg
# datasets/mushrooms/oyster/441.jpg
# datasets/mushrooms/oyster/199.jpg
# datasets/mushrooms/oyster/259.jpg
# datasets/mushrooms/oyster/406.jpg
# datasets/mushrooms/oyster/376.jpg
# datasets/mushrooms/oyster/413.jpg
# datasets/mushrooms/oyster/161.jpg
# datasets/mushrooms/oyster/247.jpg
# datasets/mushrooms/oyster/77.jpg
# datasets/mushrooms/oyster/352.jpg
# datasets/mushrooms/oyster/90.jpg
# datasets/mushrooms/oyster/458.jpg
# datasets/mushrooms/oyster/125.jpg
# datasets/mushrooms/oyster/363.jpg
# datasets/mushrooms/oyster/372.jpg
# datasets/mushrooms/oyster/384.jpg
# datasets/mushrooms/oyster/570.jpg
# datasets/mushrooms/oyster/284.jpg
# datasets/mushrooms/oyster/266.jpg
# datasets/mushrooms/oyster/525.jpg
# datasets/mushrooms/oyster/468.jpg
# datasets/mushrooms/oyster/424.jpg
# datasets/mushrooms/oyster/209.jpg
# datasets/mushrooms/oyster/465.jpg
# datasets/mushrooms/oyster/237.jpg
# datasets/mushrooms/oyster/188.jpg
# datasets/mushrooms/oyster/133.jpg
# datasets/mushrooms/oyster/557.jpg
# datasets/mushrooms/oyster/315.jpg
# datasets/mushrooms/oyster/559.jpg
# datasets/mushrooms/oyster/434.jpg
# datasets/mushrooms/oyster/211.jpg
# datasets/mushrooms/oyster/386.jpg
# datasets/mushrooms/oyster/65.jpg
# datasets/mushrooms/oyster/243.jpg
# datasets/mushrooms/oyster/142.jpg
# datasets/mushrooms/oyster/450.jpg
# datasets/mushrooms/oyster/279.jpg
# datasets/mushrooms/oyster/469.jpg
# datasets/mushrooms/oyster/419.jpg
# datasets/mushrooms/oyster/473.jpg
# datasets/mushrooms/oyster/18.jpg
# datasets/mushrooms/oyster/258.jpg
# datasets/mushrooms/oyster/416.jpg
# datasets/mushrooms/oyster/254.jpg
# datasets/mushrooms/oyster/360.jpg
# datasets/mushrooms/oyster/154.jpg
# datasets/mushrooms/oyster/506.jpg
# datasets/mushrooms/oyster/106.jpg
# datasets/mushrooms/oyster/532.jpg
# datasets/mushrooms/oyster/325.jpg
# datasets/mushrooms/oyster/19.jpg
# datasets/mushrooms/oyster/93.jpg
# datasets/mushrooms/oyster/23.jpg
# datasets/mushrooms/oyster/39.jpg
# datasets/mushrooms/oyster/194.jpg
# datasets/mushrooms/oyster/408.jpg
# datasets/mushrooms/oyster/85.jpg
# datasets/mushrooms/oyster/4.jpg
# datasets/mushrooms/oyster/446.jpg
# datasets/mushrooms/oyster/262.jpg
# datasets/mushrooms/oyster/252.jpg
# datasets/mushrooms/oyster/253.jpg
# datasets/mushrooms/oyster/518.jpg
# datasets/mushrooms/oyster/56.jpg
# datasets/mushrooms/oyster/130.jpg
# datasets/mushrooms/oyster/496.jpg
# datasets/mushrooms/oyster/370.jpg
# datasets/mushrooms/oyster/102.jpg
# datasets/mushrooms/oyster/526.jpg
# datasets/mushrooms/oyster/498.jpg
# datasets/mushrooms/oyster/510.jpg
# datasets/mushrooms/oyster/155.jpg
# datasets/mushrooms/oyster/478.jpg
# datasets/mushrooms/oyster/63.jpg
# datasets/mushrooms/oyster/14.jpg
# datasets/mushrooms/oyster/332.jpg
# datasets/mushrooms/oyster/379.jpg
# datasets/mushrooms/oyster/427.jpg
# datasets/mushrooms/oyster/303.jpg
# datasets/mushrooms/oyster/354.jpg
# datasets/mushrooms/oyster/189.jpg
# datasets/mushrooms/oyster/333.jpg
# datasets/mushrooms/oyster/185.jpg
# datasets/mushrooms/oyster/451.jpg
# datasets/mushrooms/oyster/511.jpg
# datasets/mushrooms/oyster/113.jpg
# datasets/mushrooms/oyster/595.jpg
# datasets/mushrooms/oyster/378.jpg
# datasets/mushrooms/oyster/492.jpg
# datasets/mushrooms/oyster/58.jpg
# datasets/mushrooms/oyster/182.jpg
# datasets/mushrooms/oyster/357.jpg
# datasets/mushrooms/oyster/190.jpg
# datasets/mushrooms/oyster/540.jpg
# datasets/mushrooms/oyster/219.jpg
# datasets/mushrooms/oyster/414.jpg
# datasets/mushrooms/oyster/342.jpg
# datasets/mushrooms/oyster/555.jpg
# datasets/mushrooms/oyster/460.jpg
# datasets/mushrooms/oyster/311.jpg
# datasets/mushrooms/oyster/51.jpg
# datasets/mushrooms/oyster/327.jpg
# datasets/mushrooms/oyster/347.jpg
# datasets/mushrooms/oyster/483.jpg
# datasets/mushrooms/oyster/235.jpg
# datasets/mushrooms/oyster/464.jpg
# datasets/mushrooms/oyster/169.jpg
# datasets/mushrooms/oyster/28.jpg
# datasets/mushrooms/oyster/149.jpg
# datasets/mushrooms/oyster/83.jpg
# datasets/mushrooms/oyster/572.jpg
# datasets/mushrooms/oyster/139.jpg
# datasets/mushrooms/oyster/248.jpg
# datasets/mushrooms/oyster/524.jpg
# datasets/mushrooms/oyster/150.jpg
# datasets/mushrooms/oyster/176.jpg
# datasets/mushrooms/oyster/486.jpg
# datasets/mushrooms/oyster/159.jpg
# datasets/mushrooms/oyster/206.jpg
# datasets/mushrooms/oyster/138.jpg
# datasets/mushrooms/oyster/184.jpg
# datasets/mushrooms/oyster/571.jpg
# datasets/mushrooms/oyster/578.jpg
# datasets/mushrooms/oyster/250.jpg
# datasets/mushrooms/oyster/599.jpg
# datasets/mushrooms/oyster/503.jpg
# datasets/mushrooms/oyster/72.jpg
# datasets/mushrooms/oyster/310.jpg
# datasets/mushrooms/oyster/198.jpg
# datasets/mushrooms/oyster/286.jpg
# datasets/mushrooms/oyster/171.jpg
# datasets/mushrooms/oyster/519.jpg
# datasets/mushrooms/oyster/60.jpg
# datasets/mushrooms/oyster/112.jpg
# datasets/mushrooms/oyster/516.jpg
# datasets/mushrooms/oyster/587.jpg
# datasets/mushrooms/oyster/447.jpg
# datasets/mushrooms/oyster/558.jpg
# datasets/mushrooms/oyster/224.jpg
# datasets/mushrooms/oyster/167.jpg
# datasets/mushrooms/oyster/534.jpg
# datasets/mushrooms/oyster/375.jpg
# datasets/mushrooms/oyster/353.jpg
# datasets/mushrooms/oyster/390.jpg
# datasets/mushrooms/oyster/168.jpg
# datasets/mushrooms/oyster/87.jpg
# datasets/mushrooms/oyster/141.jpg
# datasets/mushrooms/oyster/47.jpg
# datasets/mushrooms/oyster/445.jpg
# datasets/mushrooms/oyster/589.jpg
# datasets/mushrooms/oyster/212.jpg
# datasets/mushrooms/oyster/148.jpg
# datasets/mushrooms/oyster/84.jpg
# datasets/mushrooms/oyster/573.jpg
# datasets/mushrooms/oyster/22.jpg
# datasets/mushrooms/oyster/21.jpg
# datasets/mushrooms/oyster/397.jpg
# datasets/mushrooms/oyster/74.jpg
# datasets/mushrooms/oyster/229.jpg
# datasets/mushrooms/oyster/68.jpg
# datasets/mushrooms/oyster/487.jpg
# datasets/mushrooms/oyster/88.jpg
# datasets/mushrooms/oyster/43.jpg
# datasets/mushrooms/oyster/344.jpg
# datasets/mushrooms/oyster/48.jpg
# datasets/mushrooms/oyster/514.jpg
# datasets/mushrooms/oyster/96.jpg
# datasets/mushrooms/oyster/12.jpg
# datasets/mushrooms/oyster/598.jpg
# datasets/mushrooms/oyster/108.jpg
# datasets/mushrooms/oyster/415.jpg
# datasets/mushrooms/oyster/475.jpg
# datasets/mushrooms/oyster/382.jpg
# datasets/mushrooms/oyster/453.jpg
# datasets/mushrooms/oyster/57.jpg
# datasets/mushrooms/oyster/166.jpg
# datasets/mushrooms/oyster/249.jpg
# datasets/mushrooms/oyster/246.jpg
# datasets/mushrooms/oyster/480.jpg
# datasets/mushrooms/oyster/438.jpg
# datasets/mushrooms/oyster/78.jpg
# datasets/mushrooms/oyster/307.jpg
# datasets/mushrooms/oyster/300.jpg
# datasets/mushrooms/oyster/322.jpg
# datasets/mushrooms/oyster/29.jpg
# datasets/mushrooms/oyster/439.jpg
# datasets/mushrooms/oyster/549.jpg
# datasets/mushrooms/oyster/394.jpg
# datasets/mushrooms/oyster/351.jpg
# datasets/mushrooms/oyster/244.jpg
# datasets/mushrooms/oyster/137.jpg
# datasets/mushrooms/oyster/346.jpg
# datasets/mushrooms/oyster/215.jpg
# datasets/mushrooms/oyster/449.jpg
# datasets/mushrooms/oyster/410.jpg
# datasets/mushrooms/oyster/544.jpg
# datasets/mushrooms/oyster/162.jpg
# datasets/mushrooms/oyster/539.jpg
# datasets/mushrooms/oyster/304.jpg
# datasets/mushrooms/oyster/180.jpg
# datasets/mushrooms/oyster/436.jpg
# datasets/mushrooms/oyster/407.jpg
# datasets/mushrooms/oyster/330.jpg
# datasets/mushrooms/oyster/156.jpg
# datasets/mushrooms/oyster/320.jpg
# datasets/mushrooms/oyster/541.jpg
# datasets/mushrooms/oyster/432.jpg
# datasets/mushrooms/oyster/267.jpg
# datasets/mushrooms/oyster/527.jpg
# datasets/mushrooms/oyster/118.jpg
# datasets/mushrooms/oyster/208.jpg
# datasets/mushrooms/oyster/99.jpg
# datasets/mushrooms/oyster/257.jpg
# datasets/mushrooms/oyster/501.jpg
# datasets/mushrooms/oyster/174.jpg
# datasets/mushrooms/oyster/584.jpg
# datasets/mushrooms/oyster/398.jpg
# datasets/mushrooms/oyster/175.jpg
# datasets/mushrooms/oyster/302.jpg
# datasets/mushrooms/oyster/551.jpg
# datasets/mushrooms/oyster/10.jpg
# datasets/mushrooms/oyster/308.jpg
# datasets/mushrooms/oyster/385.jpg
# datasets/mushrooms/oyster/5.jpg
# datasets/mushrooms/oyster/263.jpg
# datasets/mushrooms/oyster/306.jpg
# datasets/mushrooms/oyster/481.jpg
# datasets/mushrooms/oyster/298.jpg
# datasets/mushrooms/oyster/0.jpg
# datasets/mushrooms/oyster/233.jpg
# datasets/mushrooms/oyster/466.jpg
# datasets/mushrooms/oyster/197.jpg
# datasets/mushrooms/oyster/437.jpg
# datasets/mushrooms/oyster/45.jpg
# datasets/mushrooms/oyster/377.jpg
# datasets/mushrooms/oyster/443.jpg
# datasets/mushrooms/oyster/16.jpg
# datasets/mushrooms/oyster/488.jpg
# datasets/mushrooms/oyster/485.jpg
# datasets/mushrooms/oyster/581.jpg
# datasets/mushrooms/oyster/225.jpg
# datasets/mushrooms/oyster/484.jpg
# datasets/mushrooms/oyster/513.jpg
# datasets/mushrooms/oyster/181.jpg
# datasets/mushrooms/oyster/207.jpg
# datasets/mushrooms/oyster/495.jpg
# datasets/mushrooms/oyster/30.jpg
# datasets/mushrooms/oyster/582.jpg
# datasets/mushrooms/oyster/521.jpg
# datasets/mushrooms/oyster/186.jpg
# datasets/mushrooms/oyster/230.jpg
# datasets/mushrooms/oyster/565.jpg
# datasets/mushrooms/oyster/405.jpg
# datasets/mushrooms/oyster/178.jpg
# datasets/mushrooms/oyster/552.jpg
# datasets/mushrooms/oyster/201.jpg
# datasets/mushrooms/oyster/409.jpg
# datasets/mushrooms/oyster/435.jpg
# datasets/mushrooms/oyster/97.jpg
# datasets/mushrooms/oyster/362.jpg
# datasets/mushrooms/oyster/502.jpg
# datasets/mushrooms/oyster/80.jpg
# datasets/mushrooms/oyster/433.jpg
# datasets/mushrooms/oyster/364.jpg
# datasets/mushrooms/oyster/355.jpg
# datasets/mushrooms/oyster/530.jpg
# datasets/mushrooms/oyster/34.jpg
# datasets/mushrooms/oyster/73.jpg
# datasets/mushrooms/oyster/350.jpg
# datasets/mushrooms/oyster/40.jpg
# datasets/mushrooms/oyster/165.jpg
# datasets/mushrooms/oyster/280.jpg
# datasets/mushrooms/oyster/31.jpg
# datasets/mushrooms/oyster/403.jpg
# datasets/mushrooms/oyster/238.jpg
# datasets/mushrooms/oyster/563.jpg
# datasets/mushrooms/oyster/239.jpg
# datasets/mushrooms/oyster/420.jpg
# datasets/mushrooms/oyster/110.jpg
# datasets/mushrooms/oyster/135.jpg
# datasets/mushrooms/oyster/430.jpg
# datasets/mushrooms/oyster/348.jpg
# datasets/mushrooms/oyster/313.jpg
# datasets/mushrooms/oyster/27.jpg
# datasets/mushrooms/oyster/203.jpg
# datasets/mushrooms/oyster/358.jpg
# datasets/mushrooms/oyster/482.jpg
# datasets/mushrooms/oyster/111.jpg
# datasets/mushrooms/oyster/231.jpg
# datasets/mushrooms/oyster/122.jpg
# datasets/mushrooms/oyster/9.jpg
# datasets/mushrooms/oyster/554.jpg
# datasets/mushrooms/oyster/95.jpg
# datasets/mushrooms/oyster/187.jpg
# datasets/mushrooms/oyster/454.jpg
# datasets/mushrooms/oyster/374.jpg
# datasets/mushrooms/oyster/566.jpg
# datasets/mushrooms/amanita/401.jpg
# datasets/mushrooms/amanita/226.jpg
# datasets/mushrooms/amanita/261.jpg
# datasets/mushrooms/amanita/412.jpg
# datasets/mushrooms/amanita/508.jpg
# datasets/mushrooms/amanita/41.jpg
# datasets/mushrooms/amanita/124.jpg
# datasets/mushrooms/amanita/553.jpg
# datasets/mushrooms/amanita/210.jpg
# datasets/mushrooms/amanita/381.jpg
# datasets/mushrooms/amanita/17.jpg
# datasets/mushrooms/amanita/38.jpg
# datasets/mushrooms/amanita/79.jpg
# datasets/mushrooms/amanita/456.jpg
# datasets/mushrooms/amanita/274.jpg
# datasets/mushrooms/amanita/264.jpg
# datasets/mushrooms/amanita/7.jpg
# datasets/mushrooms/amanita/461.jpg
# datasets/mushrooms/amanita/337.jpg
# datasets/mushrooms/amanita/101.jpg
# datasets/mushrooms/amanita/20.jpg
# datasets/mushrooms/amanita/223.jpg
# datasets/mushrooms/amanita/457.jpg
# datasets/mushrooms/amanita/119.jpg
# datasets/mushrooms/amanita/328.jpg
# datasets/mushrooms/amanita/440.jpg
# datasets/mushrooms/amanita/153.jpg
# datasets/mushrooms/amanita/431.jpg
# datasets/mushrooms/amanita/50.jpg
# datasets/mushrooms/amanita/71.jpg
# datasets/mushrooms/amanita/15.jpg
# datasets/mushrooms/amanita/489.jpg
# datasets/mushrooms/amanita/116.jpg
# datasets/mushrooms/amanita/542.jpg
# datasets/mushrooms/amanita/256.jpg
# datasets/mushrooms/amanita/533.jpg
# datasets/mushrooms/amanita/35.jpg
# datasets/mushrooms/amanita/272.jpg
# datasets/mushrooms/amanita/391.jpg
# datasets/mushrooms/amanita/476.jpg
# datasets/mushrooms/amanita/497.jpg
# datasets/mushrooms/amanita/8.jpg
# datasets/mushrooms/amanita/251.jpg
# datasets/mushrooms/amanita/395.jpg
# datasets/mushrooms/amanita/245.jpg
# datasets/mushrooms/amanita/538.jpg
# datasets/mushrooms/amanita/105.jpg
# datasets/mushrooms/amanita/205.jpg
# datasets/mushrooms/amanita/1.jpg
# datasets/mushrooms/amanita/561.jpg
# datasets/mushrooms/amanita/345.jpg
# datasets/mushrooms/amanita/556.jpg
# datasets/mushrooms/amanita/287.jpg
# datasets/mushrooms/amanita/236.jpg
# datasets/mushrooms/amanita/268.jpg
# datasets/mushrooms/amanita/500.jpg
# datasets/mushrooms/amanita/455.jpg
# datasets/mushrooms/amanita/299.jpg
# datasets/mushrooms/amanita/86.jpg
# datasets/mushrooms/amanita/545.jpg
# datasets/mushrooms/amanita/183.jpg
# datasets/mushrooms/amanita/126.jpg
# datasets/mushrooms/amanita/548.jpg
# datasets/mushrooms/amanita/290.jpg
# datasets/mushrooms/amanita/192.jpg
# datasets/mushrooms/amanita/213.jpg
# datasets/mushrooms/amanita/550.jpg
# datasets/mushrooms/amanita/13.jpg
# datasets/mushrooms/amanita/399.jpg
# datasets/mushrooms/amanita/336.jpg
# datasets/mushrooms/amanita/270.jpg
# datasets/mushrooms/amanita/269.jpg
# datasets/mushrooms/amanita/25.jpg
# datasets/mushrooms/amanita/442.jpg
# datasets/mushrooms/amanita/129.jpg
# datasets/mushrooms/amanita/423.jpg
# datasets/mushrooms/amanita/452.jpg
# datasets/mushrooms/amanita/144.jpg
# datasets/mushrooms/amanita/114.jpg
# datasets/mushrooms/amanita/341.jpg
# datasets/mushrooms/amanita/195.jpg
# datasets/mushrooms/amanita/107.jpg
# datasets/mushrooms/amanita/536.jpg
# datasets/mushrooms/amanita/537.jpg
# datasets/mushrooms/amanita/371.jpg
# datasets/mushrooms/amanita/520.jpg
# datasets/mushrooms/amanita/463.jpg
# datasets/mushrooms/amanita/477.jpg
# datasets/mushrooms/amanita/546.jpg
# datasets/mushrooms/amanita/425.jpg
# datasets/mushrooms/amanita/120.jpg
# datasets/mushrooms/amanita/393.jpg
# datasets/mushrooms/amanita/288.jpg
# datasets/mushrooms/amanita/103.jpg
# datasets/mushrooms/amanita/417.jpg
# datasets/mushrooms/amanita/75.jpg
# datasets/mushrooms/amanita/283.jpg
# datasets/mushrooms/amanita/522.jpg
# datasets/mushrooms/amanita/380.jpg
# datasets/mushrooms/amanita/3.jpg
# datasets/mushrooms/amanita/222.jpg
# datasets/mushrooms/amanita/52.jpg
# datasets/mushrooms/amanita/115.jpg
# datasets/mushrooms/amanita/387.jpg
# datasets/mushrooms/amanita/94.jpg
# datasets/mushrooms/amanita/117.jpg
# datasets/mushrooms/amanita/273.jpg
# datasets/mushrooms/amanita/577.jpg
# datasets/mushrooms/amanita/140.jpg
# datasets/mushrooms/amanita/91.jpg
# datasets/mushrooms/amanita/26.jpg
# datasets/mushrooms/amanita/569.jpg
# datasets/mushrooms/amanita/365.jpg
# datasets/mushrooms/amanita/285.jpg
# datasets/mushrooms/amanita/146.jpg
# datasets/mushrooms/amanita/329.jpg
# datasets/mushrooms/amanita/490.jpg
# datasets/mushrooms/amanita/6.jpg
# datasets/mushrooms/amanita/515.jpg
# datasets/mushrooms/amanita/173.jpg
# datasets/mushrooms/amanita/421.jpg
# datasets/mushrooms/amanita/305.jpg
# datasets/mushrooms/amanita/331.jpg
# datasets/mushrooms/amanita/517.jpg
# datasets/mushrooms/amanita/349.jpg
# datasets/mushrooms/amanita/276.jpg
# datasets/mushrooms/amanita/32.jpg
# datasets/mushrooms/amanita/292.jpg
# datasets/mushrooms/amanita/422.jpg
# datasets/mushrooms/amanita/33.jpg
# datasets/mushrooms/amanita/334.jpg
# datasets/mushrooms/amanita/479.jpg
# datasets/mushrooms/amanita/221.jpg
# datasets/mushrooms/amanita/132.jpg
# datasets/mushrooms/amanita/11.jpg
# datasets/mushrooms/amanita/216.jpg
# datasets/mushrooms/amanita/296.jpg
# datasets/mushrooms/amanita/366.jpg
# datasets/mushrooms/amanita/392.jpg
# datasets/mushrooms/amanita/260.jpg
# datasets/mushrooms/amanita/318.jpg
# datasets/mushrooms/amanita/404.jpg
# datasets/mushrooms/amanita/164.jpg
# datasets/mushrooms/amanita/157.jpg
# datasets/mushrooms/amanita/574.jpg
# datasets/mushrooms/amanita/100.jpg
# datasets/mushrooms/amanita/326.jpg
# datasets/mushrooms/amanita/389.jpg
# datasets/mushrooms/amanita/275.jpg
# datasets/mushrooms/amanita/579.jpg
# datasets/mushrooms/amanita/191.jpg
# datasets/mushrooms/amanita/494.jpg
# datasets/mushrooms/amanita/448.jpg
# datasets/mushrooms/amanita/472.jpg
# datasets/mushrooms/amanita/37.jpg
# datasets/mushrooms/amanita/255.jpg
# datasets/mushrooms/amanita/66.jpg
# datasets/mushrooms/amanita/335.jpg
# datasets/mushrooms/amanita/560.jpg
# datasets/mushrooms/amanita/76.jpg
# datasets/mushrooms/amanita/396.jpg
# datasets/mushrooms/amanita/316.jpg
# datasets/mushrooms/amanita/241.jpg
# datasets/mushrooms/amanita/64.jpg
# datasets/mushrooms/amanita/98.jpg
# datasets/mushrooms/amanita/240.jpg
# datasets/mushrooms/amanita/467.jpg
# datasets/mushrooms/amanita/340.jpg
# datasets/mushrooms/amanita/55.jpg
# datasets/mushrooms/amanita/512.jpg
# datasets/mushrooms/amanita/523.jpg
# datasets/mushrooms/amanita/278.jpg
# datasets/mushrooms/amanita/505.jpg
# datasets/mushrooms/amanita/232.jpg
# datasets/mushrooms/amanita/143.jpg
# datasets/mushrooms/amanita/265.jpg
# datasets/mushrooms/amanita/400.jpg
# datasets/mushrooms/amanita/388.jpg
# datasets/mushrooms/amanita/136.jpg
# datasets/mushrooms/amanita/70.jpg
# datasets/mushrooms/amanita/217.jpg
# datasets/mushrooms/amanita/367.jpg
# datasets/mushrooms/amanita/24.jpg
# datasets/mushrooms/amanita/277.jpg
# datasets/mushrooms/amanita/172.jpg
# datasets/mushrooms/amanita/109.jpg
# datasets/mushrooms/amanita/323.jpg
# datasets/mushrooms/amanita/42.jpg
# datasets/mushrooms/amanita/312.jpg
# datasets/mushrooms/amanita/59.jpg
# datasets/mushrooms/amanita/82.jpg
# datasets/mushrooms/amanita/383.jpg
# datasets/mushrooms/amanita/459.jpg
# datasets/mushrooms/amanita/444.jpg
# datasets/mushrooms/amanita/317.jpg
# datasets/mushrooms/amanita/61.jpg
# datasets/mushrooms/amanita/338.jpg
# datasets/mushrooms/amanita/314.jpg
# datasets/mushrooms/amanita/228.jpg
# datasets/mushrooms/amanita/547.jpg
# datasets/mushrooms/amanita/562.jpg
# datasets/mushrooms/amanita/309.jpg
# datasets/mushrooms/amanita/193.jpg
# datasets/mushrooms/amanita/220.jpg
# datasets/mushrooms/amanita/92.jpg
# datasets/mushrooms/amanita/204.jpg
# datasets/mushrooms/amanita/81.jpg
# datasets/mushrooms/amanita/49.jpg
# datasets/mushrooms/amanita/504.jpg
# datasets/mushrooms/amanita/319.jpg
# datasets/mushrooms/amanita/301.jpg
# datasets/mushrooms/amanita/339.jpg
# datasets/mushrooms/amanita/293.jpg
# datasets/mushrooms/amanita/361.jpg
# datasets/mushrooms/amanita/131.jpg
# datasets/mushrooms/amanita/294.jpg
# datasets/mushrooms/amanita/44.jpg
# datasets/mushrooms/amanita/160.jpg
# datasets/mushrooms/amanita/324.jpg
# datasets/mushrooms/amanita/145.jpg
# datasets/mushrooms/amanita/163.jpg
# datasets/mushrooms/amanita/54.jpg
# datasets/mushrooms/amanita/576.jpg
# datasets/mushrooms/amanita/368.jpg
# datasets/mushrooms/amanita/62.jpg
# datasets/mushrooms/amanita/281.jpg
# datasets/mushrooms/amanita/474.jpg
# datasets/mushrooms/amanita/564.jpg
# datasets/mushrooms/amanita/36.jpg
# datasets/mushrooms/amanita/359.jpg
# datasets/mushrooms/amanita/493.jpg
# datasets/mushrooms/amanita/568.jpg
# datasets/mushrooms/amanita/426.jpg
# datasets/mushrooms/amanita/429.jpg
# datasets/mushrooms/amanita/89.jpg
# datasets/mushrooms/amanita/158.jpg
# datasets/mushrooms/amanita/69.jpg
# datasets/mushrooms/amanita/528.jpg
# datasets/mushrooms/amanita/411.jpg
# datasets/mushrooms/amanita/218.jpg
# datasets/mushrooms/amanita/373.jpg
# datasets/mushrooms/amanita/199.jpg
# datasets/mushrooms/amanita/259.jpg
# datasets/mushrooms/amanita/406.jpg
# datasets/mushrooms/amanita/543.jpg
# datasets/mushrooms/amanita/376.jpg
# datasets/mushrooms/amanita/413.jpg
# datasets/mushrooms/amanita/247.jpg
# datasets/mushrooms/amanita/77.jpg
# datasets/mushrooms/amanita/352.jpg
# datasets/mushrooms/amanita/90.jpg
# datasets/mushrooms/amanita/458.jpg
# datasets/mushrooms/amanita/363.jpg
# datasets/mushrooms/amanita/372.jpg
# datasets/mushrooms/amanita/384.jpg
# datasets/mushrooms/amanita/570.jpg
# datasets/mushrooms/amanita/284.jpg
# datasets/mushrooms/amanita/266.jpg
# datasets/mushrooms/amanita/525.jpg
# datasets/mushrooms/amanita/468.jpg
# datasets/mushrooms/amanita/424.jpg
# datasets/mushrooms/amanita/209.jpg
# datasets/mushrooms/amanita/465.jpg
# datasets/mushrooms/amanita/237.jpg
# datasets/mushrooms/amanita/188.jpg
# datasets/mushrooms/amanita/133.jpg
# datasets/mushrooms/amanita/557.jpg
# datasets/mushrooms/amanita/315.jpg
# datasets/mushrooms/amanita/567.jpg
# datasets/mushrooms/amanita/559.jpg
# datasets/mushrooms/amanita/434.jpg
# datasets/mushrooms/amanita/211.jpg
# datasets/mushrooms/amanita/386.jpg
# datasets/mushrooms/amanita/65.jpg
# datasets/mushrooms/amanita/243.jpg
# datasets/mushrooms/amanita/142.jpg
# datasets/mushrooms/amanita/450.jpg
# datasets/mushrooms/amanita/279.jpg
# datasets/mushrooms/amanita/469.jpg
# datasets/mushrooms/amanita/419.jpg
# datasets/mushrooms/amanita/18.jpg
# datasets/mushrooms/amanita/258.jpg
# datasets/mushrooms/amanita/416.jpg
# datasets/mushrooms/amanita/360.jpg
# datasets/mushrooms/amanita/506.jpg
# datasets/mushrooms/amanita/106.jpg
# datasets/mushrooms/amanita/532.jpg
# datasets/mushrooms/amanita/325.jpg
# datasets/mushrooms/amanita/19.jpg
# datasets/mushrooms/amanita/93.jpg
# datasets/mushrooms/amanita/23.jpg
# datasets/mushrooms/amanita/196.jpg
# datasets/mushrooms/amanita/39.jpg
# datasets/mushrooms/amanita/194.jpg
# datasets/mushrooms/amanita/408.jpg
# datasets/mushrooms/amanita/85.jpg
# datasets/mushrooms/amanita/4.jpg
# datasets/mushrooms/amanita/446.jpg
# datasets/mushrooms/amanita/252.jpg
# datasets/mushrooms/amanita/253.jpg
# datasets/mushrooms/amanita/518.jpg
# datasets/mushrooms/amanita/56.jpg
# datasets/mushrooms/amanita/509.jpg
# datasets/mushrooms/amanita/130.jpg
# datasets/mushrooms/amanita/179.jpg
# datasets/mushrooms/amanita/496.jpg
# datasets/mushrooms/amanita/370.jpg
# datasets/mushrooms/amanita/295.jpg
# datasets/mushrooms/amanita/102.jpg
# datasets/mushrooms/amanita/526.jpg
# datasets/mushrooms/amanita/498.jpg
# datasets/mushrooms/amanita/510.jpg
# datasets/mushrooms/amanita/155.jpg
# datasets/mushrooms/amanita/478.jpg
# datasets/mushrooms/amanita/63.jpg
# datasets/mushrooms/amanita/14.jpg
# datasets/mushrooms/amanita/379.jpg
# datasets/mushrooms/amanita/427.jpg
# datasets/mushrooms/amanita/303.jpg
# datasets/mushrooms/amanita/354.jpg
# datasets/mushrooms/amanita/189.jpg
# datasets/mushrooms/amanita/333.jpg
# datasets/mushrooms/amanita/451.jpg
# datasets/mushrooms/amanita/511.jpg
# datasets/mushrooms/amanita/113.jpg
# datasets/mushrooms/amanita/378.jpg
# datasets/mushrooms/amanita/492.jpg
# datasets/mushrooms/amanita/471.jpg
# datasets/mushrooms/amanita/58.jpg
# datasets/mushrooms/amanita/182.jpg
# datasets/mushrooms/amanita/357.jpg
# datasets/mushrooms/amanita/540.jpg
# datasets/mushrooms/amanita/219.jpg
# datasets/mushrooms/amanita/414.jpg
# datasets/mushrooms/amanita/342.jpg
# datasets/mushrooms/amanita/555.jpg
# datasets/mushrooms/amanita/460.jpg
# datasets/mushrooms/amanita/311.jpg
# datasets/mushrooms/amanita/51.jpg
# datasets/mushrooms/amanita/327.jpg
# datasets/mushrooms/amanita/347.jpg
# datasets/mushrooms/amanita/462.jpg
# datasets/mushrooms/amanita/483.jpg
# datasets/mushrooms/amanita/235.jpg
# datasets/mushrooms/amanita/464.jpg
# datasets/mushrooms/amanita/169.jpg
# datasets/mushrooms/amanita/28.jpg
# datasets/mushrooms/amanita/149.jpg
# datasets/mushrooms/amanita/343.jpg
# datasets/mushrooms/amanita/83.jpg
# datasets/mushrooms/amanita/572.jpg
# datasets/mushrooms/amanita/139.jpg
# datasets/mushrooms/amanita/248.jpg
# datasets/mushrooms/amanita/524.jpg
# datasets/mushrooms/amanita/470.jpg
# datasets/mushrooms/amanita/150.jpg
# datasets/mushrooms/amanita/176.jpg
# datasets/mushrooms/amanita/486.jpg
# datasets/mushrooms/amanita/289.jpg
# datasets/mushrooms/amanita/159.jpg
# datasets/mushrooms/amanita/206.jpg
# datasets/mushrooms/amanita/138.jpg
# datasets/mushrooms/amanita/356.jpg
# datasets/mushrooms/amanita/571.jpg
# datasets/mushrooms/amanita/214.jpg
# datasets/mushrooms/amanita/578.jpg
# datasets/mushrooms/amanita/250.jpg
# datasets/mushrooms/amanita/503.jpg
# datasets/mushrooms/amanita/72.jpg
# datasets/mushrooms/amanita/310.jpg
# datasets/mushrooms/amanita/198.jpg
# datasets/mushrooms/amanita/286.jpg
# datasets/mushrooms/amanita/171.jpg
# datasets/mushrooms/amanita/519.jpg
# datasets/mushrooms/amanita/60.jpg
# datasets/mushrooms/amanita/112.jpg
# datasets/mushrooms/amanita/516.jpg
# datasets/mushrooms/amanita/447.jpg
# datasets/mushrooms/amanita/558.jpg
# datasets/mushrooms/amanita/167.jpg
# datasets/mushrooms/amanita/534.jpg
# datasets/mushrooms/amanita/282.jpg
# datasets/mushrooms/amanita/375.jpg
# datasets/mushrooms/amanita/353.jpg
# datasets/mushrooms/amanita/390.jpg
# datasets/mushrooms/amanita/87.jpg
# datasets/mushrooms/amanita/141.jpg
# datasets/mushrooms/amanita/47.jpg
# datasets/mushrooms/amanita/445.jpg
# datasets/mushrooms/amanita/212.jpg
# datasets/mushrooms/amanita/148.jpg
# datasets/mushrooms/amanita/84.jpg
# datasets/mushrooms/amanita/573.jpg
# datasets/mushrooms/amanita/22.jpg
# datasets/mushrooms/amanita/21.jpg
# datasets/mushrooms/amanita/397.jpg
# datasets/mushrooms/amanita/74.jpg
# datasets/mushrooms/amanita/229.jpg
# datasets/mushrooms/amanita/68.jpg
# datasets/mushrooms/amanita/487.jpg
# datasets/mushrooms/amanita/88.jpg
# datasets/mushrooms/amanita/43.jpg
# datasets/mushrooms/amanita/344.jpg
# datasets/mushrooms/amanita/514.jpg
# datasets/mushrooms/amanita/152.jpg
# datasets/mushrooms/amanita/96.jpg
# datasets/mushrooms/amanita/12.jpg
# datasets/mushrooms/amanita/108.jpg
# datasets/mushrooms/amanita/418.jpg
# datasets/mushrooms/amanita/121.jpg
# datasets/mushrooms/amanita/415.jpg
# datasets/mushrooms/amanita/475.jpg
# datasets/mushrooms/amanita/382.jpg
# datasets/mushrooms/amanita/453.jpg
# datasets/mushrooms/amanita/57.jpg
# datasets/mushrooms/amanita/166.jpg
# datasets/mushrooms/amanita/249.jpg
# datasets/mushrooms/amanita/246.jpg
# datasets/mushrooms/amanita/480.jpg
# datasets/mushrooms/amanita/438.jpg
# datasets/mushrooms/amanita/78.jpg
# datasets/mushrooms/amanita/307.jpg
# datasets/mushrooms/amanita/300.jpg
# datasets/mushrooms/amanita/322.jpg
# datasets/mushrooms/amanita/29.jpg
# datasets/mushrooms/amanita/439.jpg
# datasets/mushrooms/amanita/549.jpg
# datasets/mushrooms/amanita/394.jpg
# datasets/mushrooms/amanita/244.jpg
# datasets/mushrooms/amanita/402.jpg
# datasets/mushrooms/amanita/137.jpg
# datasets/mushrooms/amanita/346.jpg
# datasets/mushrooms/amanita/215.jpg
# datasets/mushrooms/amanita/449.jpg
# datasets/mushrooms/amanita/410.jpg
# datasets/mushrooms/amanita/544.jpg
# datasets/mushrooms/amanita/162.jpg
# datasets/mushrooms/amanita/539.jpg
# datasets/mushrooms/amanita/304.jpg
# datasets/mushrooms/amanita/180.jpg
# datasets/mushrooms/amanita/436.jpg
# datasets/mushrooms/amanita/407.jpg
# datasets/mushrooms/amanita/330.jpg
# datasets/mushrooms/amanita/151.jpg
# datasets/mushrooms/amanita/156.jpg
# datasets/mushrooms/amanita/320.jpg
# datasets/mushrooms/amanita/541.jpg
# datasets/mushrooms/amanita/432.jpg
# datasets/mushrooms/amanita/267.jpg
# datasets/mushrooms/amanita/527.jpg
# datasets/mushrooms/amanita/118.jpg
# datasets/mushrooms/amanita/531.jpg
# datasets/mushrooms/amanita/99.jpg
# datasets/mushrooms/amanita/501.jpg
# datasets/mushrooms/amanita/174.jpg
# datasets/mushrooms/amanita/398.jpg
# datasets/mushrooms/amanita/175.jpg
# datasets/mushrooms/amanita/302.jpg
# datasets/mushrooms/amanita/551.jpg
# datasets/mushrooms/amanita/10.jpg
# datasets/mushrooms/amanita/308.jpg
# datasets/mushrooms/amanita/234.jpg
# datasets/mushrooms/amanita/385.jpg
# datasets/mushrooms/amanita/507.jpg
# datasets/mushrooms/amanita/5.jpg
# datasets/mushrooms/amanita/263.jpg
# datasets/mushrooms/amanita/306.jpg
# datasets/mushrooms/amanita/481.jpg
# datasets/mushrooms/amanita/298.jpg
# datasets/mushrooms/amanita/53.jpg
# datasets/mushrooms/amanita/0.jpg
# datasets/mushrooms/amanita/233.jpg
# datasets/mushrooms/amanita/466.jpg
# datasets/mushrooms/amanita/197.jpg
# datasets/mushrooms/amanita/437.jpg
# datasets/mushrooms/amanita/45.jpg
# datasets/mushrooms/amanita/377.jpg
# datasets/mushrooms/amanita/443.jpg
# datasets/mushrooms/amanita/16.jpg
# datasets/mushrooms/amanita/488.jpg
# datasets/mushrooms/amanita/485.jpg
# datasets/mushrooms/amanita/225.jpg
# datasets/mushrooms/amanita/484.jpg
# datasets/mushrooms/amanita/513.jpg
# datasets/mushrooms/amanita/181.jpg
# datasets/mushrooms/amanita/207.jpg
# datasets/mushrooms/amanita/495.jpg
# datasets/mushrooms/amanita/30.jpg
# datasets/mushrooms/amanita/521.jpg
# datasets/mushrooms/amanita/200.jpg
# datasets/mushrooms/amanita/186.jpg
# datasets/mushrooms/amanita/230.jpg
# datasets/mushrooms/amanita/565.jpg
# datasets/mushrooms/amanita/178.jpg
# datasets/mushrooms/amanita/201.jpg
# datasets/mushrooms/amanita/409.jpg
# datasets/mushrooms/amanita/435.jpg
# datasets/mushrooms/amanita/97.jpg
# datasets/mushrooms/amanita/362.jpg
# datasets/mushrooms/amanita/502.jpg
# datasets/mushrooms/amanita/80.jpg
# datasets/mushrooms/amanita/433.jpg
# datasets/mushrooms/amanita/364.jpg
# datasets/mushrooms/amanita/355.jpg
# datasets/mushrooms/amanita/530.jpg
# datasets/mushrooms/amanita/34.jpg
# datasets/mushrooms/amanita/73.jpg
# datasets/mushrooms/amanita/350.jpg
# datasets/mushrooms/amanita/40.jpg
# datasets/mushrooms/amanita/165.jpg
# datasets/mushrooms/amanita/67.jpg
# datasets/mushrooms/amanita/280.jpg
# datasets/mushrooms/amanita/31.jpg
# datasets/mushrooms/amanita/403.jpg
# datasets/mushrooms/amanita/238.jpg
# datasets/mushrooms/amanita/563.jpg
# datasets/mushrooms/amanita/239.jpg
# datasets/mushrooms/amanita/420.jpg
# datasets/mushrooms/amanita/430.jpg
# datasets/mushrooms/amanita/348.jpg
# datasets/mushrooms/amanita/313.jpg
# datasets/mushrooms/amanita/291.jpg
# datasets/mushrooms/amanita/203.jpg
# datasets/mushrooms/amanita/358.jpg
# datasets/mushrooms/amanita/535.jpg
# datasets/mushrooms/amanita/482.jpg
# datasets/mushrooms/amanita/111.jpg
# datasets/mushrooms/amanita/231.jpg
# datasets/mushrooms/amanita/122.jpg
# datasets/mushrooms/amanita/554.jpg
# datasets/mushrooms/amanita/95.jpg
# datasets/mushrooms/amanita/187.jpg
# datasets/mushrooms/amanita/454.jpg
# datasets/mushrooms/amanita/374.jpg
# datasets/mushrooms/amanita/566.jpg
# datasets/mushrooms/crimini/401.jpg
# datasets/mushrooms/crimini/226.jpg
# datasets/mushrooms/crimini/428.jpg
# datasets/mushrooms/crimini/261.jpg
# datasets/mushrooms/crimini/412.jpg
# datasets/mushrooms/crimini/508.jpg
# datasets/mushrooms/crimini/41.jpg
# datasets/mushrooms/crimini/124.jpg
# datasets/mushrooms/crimini/553.jpg
# datasets/mushrooms/crimini/210.jpg
# datasets/mushrooms/crimini/381.jpg
# datasets/mushrooms/crimini/596.jpg
# datasets/mushrooms/crimini/17.jpg
# datasets/mushrooms/crimini/38.jpg
# datasets/mushrooms/crimini/79.jpg
# datasets/mushrooms/crimini/274.jpg
# datasets/mushrooms/crimini/264.jpg
# datasets/mushrooms/crimini/7.jpg
# datasets/mushrooms/crimini/461.jpg
# datasets/mushrooms/crimini/337.jpg
# datasets/mushrooms/crimini/101.jpg
# datasets/mushrooms/crimini/20.jpg
# datasets/mushrooms/crimini/223.jpg
# datasets/mushrooms/crimini/457.jpg
# datasets/mushrooms/crimini/119.jpg
# datasets/mushrooms/crimini/440.jpg
# datasets/mushrooms/crimini/153.jpg
# datasets/mushrooms/crimini/575.jpg
# datasets/mushrooms/crimini/431.jpg
# datasets/mushrooms/crimini/50.jpg
# datasets/mushrooms/crimini/71.jpg
# datasets/mushrooms/crimini/15.jpg
# datasets/mushrooms/crimini/489.jpg
# datasets/mushrooms/crimini/116.jpg
# datasets/mushrooms/crimini/202.jpg
# datasets/mushrooms/crimini/542.jpg
# datasets/mushrooms/crimini/256.jpg
# datasets/mushrooms/crimini/533.jpg
# datasets/mushrooms/crimini/35.jpg
# datasets/mushrooms/crimini/272.jpg
# datasets/mushrooms/crimini/391.jpg
# datasets/mushrooms/crimini/476.jpg
# datasets/mushrooms/crimini/497.jpg
# datasets/mushrooms/crimini/2.jpg
# datasets/mushrooms/crimini/8.jpg
# datasets/mushrooms/crimini/251.jpg
# datasets/mushrooms/crimini/395.jpg
# datasets/mushrooms/crimini/245.jpg
# datasets/mushrooms/crimini/538.jpg
# datasets/mushrooms/crimini/105.jpg
# datasets/mushrooms/crimini/205.jpg
# datasets/mushrooms/crimini/1.jpg
# datasets/mushrooms/crimini/561.jpg
# datasets/mushrooms/crimini/556.jpg
# datasets/mushrooms/crimini/287.jpg
# datasets/mushrooms/crimini/236.jpg
# datasets/mushrooms/crimini/268.jpg
# datasets/mushrooms/crimini/500.jpg
# datasets/mushrooms/crimini/455.jpg
# datasets/mushrooms/crimini/580.jpg
# datasets/mushrooms/crimini/299.jpg
# datasets/mushrooms/crimini/86.jpg
# datasets/mushrooms/crimini/545.jpg
# datasets/mushrooms/crimini/586.jpg
# datasets/mushrooms/crimini/588.jpg
# datasets/mushrooms/crimini/46.jpg
# datasets/mushrooms/crimini/183.jpg
# datasets/mushrooms/crimini/126.jpg
# datasets/mushrooms/crimini/548.jpg
# datasets/mushrooms/crimini/290.jpg
# datasets/mushrooms/crimini/192.jpg
# datasets/mushrooms/crimini/213.jpg
# datasets/mushrooms/crimini/550.jpg
# datasets/mushrooms/crimini/585.jpg
# datasets/mushrooms/crimini/13.jpg
# datasets/mushrooms/crimini/399.jpg
# datasets/mushrooms/crimini/336.jpg
# datasets/mushrooms/crimini/270.jpg
# datasets/mushrooms/crimini/269.jpg
# datasets/mushrooms/crimini/25.jpg
# datasets/mushrooms/crimini/442.jpg
# datasets/mushrooms/crimini/129.jpg
# datasets/mushrooms/crimini/423.jpg
# datasets/mushrooms/crimini/452.jpg
# datasets/mushrooms/crimini/144.jpg
# datasets/mushrooms/crimini/597.jpg
# datasets/mushrooms/crimini/114.jpg
# datasets/mushrooms/crimini/341.jpg
# datasets/mushrooms/crimini/195.jpg
# datasets/mushrooms/crimini/107.jpg
# datasets/mushrooms/crimini/536.jpg
# datasets/mushrooms/crimini/537.jpg
# datasets/mushrooms/crimini/371.jpg
# datasets/mushrooms/crimini/520.jpg
# datasets/mushrooms/crimini/463.jpg
# datasets/mushrooms/crimini/477.jpg
# datasets/mushrooms/crimini/546.jpg
# datasets/mushrooms/crimini/425.jpg
# datasets/mushrooms/crimini/120.jpg
# datasets/mushrooms/crimini/393.jpg
# datasets/mushrooms/crimini/288.jpg
# datasets/mushrooms/crimini/103.jpg
# datasets/mushrooms/crimini/417.jpg
# datasets/mushrooms/crimini/380.jpg
# datasets/mushrooms/crimini/222.jpg
# datasets/mushrooms/crimini/52.jpg
# datasets/mushrooms/crimini/115.jpg
# datasets/mushrooms/crimini/387.jpg
# datasets/mushrooms/crimini/592.jpg
# datasets/mushrooms/crimini/94.jpg
# datasets/mushrooms/crimini/117.jpg
# datasets/mushrooms/crimini/273.jpg
# datasets/mushrooms/crimini/577.jpg
# datasets/mushrooms/crimini/140.jpg
# datasets/mushrooms/crimini/591.jpg
# datasets/mushrooms/crimini/134.jpg
# datasets/mushrooms/crimini/321.jpg
# datasets/mushrooms/crimini/242.jpg
# datasets/mushrooms/crimini/91.jpg
# datasets/mushrooms/crimini/26.jpg
# datasets/mushrooms/crimini/569.jpg
# datasets/mushrooms/crimini/365.jpg
# datasets/mushrooms/crimini/285.jpg
# datasets/mushrooms/crimini/146.jpg
# datasets/mushrooms/crimini/329.jpg
# datasets/mushrooms/crimini/490.jpg
# datasets/mushrooms/crimini/6.jpg
# datasets/mushrooms/crimini/173.jpg
# datasets/mushrooms/crimini/421.jpg
# datasets/mushrooms/crimini/305.jpg
# datasets/mushrooms/crimini/331.jpg
# datasets/mushrooms/crimini/517.jpg
# datasets/mushrooms/crimini/276.jpg
# datasets/mushrooms/crimini/32.jpg
# datasets/mushrooms/crimini/292.jpg
# datasets/mushrooms/crimini/422.jpg
# datasets/mushrooms/crimini/33.jpg
# datasets/mushrooms/crimini/334.jpg
# datasets/mushrooms/crimini/479.jpg
# datasets/mushrooms/crimini/132.jpg
# datasets/mushrooms/crimini/11.jpg
# datasets/mushrooms/crimini/216.jpg
# datasets/mushrooms/crimini/296.jpg
# datasets/mushrooms/crimini/366.jpg
# datasets/mushrooms/crimini/392.jpg
# datasets/mushrooms/crimini/260.jpg
# datasets/mushrooms/crimini/318.jpg
# datasets/mushrooms/crimini/404.jpg
# datasets/mushrooms/crimini/164.jpg
# datasets/mushrooms/crimini/594.jpg
# datasets/mushrooms/crimini/157.jpg
# datasets/mushrooms/crimini/574.jpg
# datasets/mushrooms/crimini/128.jpg
# datasets/mushrooms/crimini/100.jpg
# datasets/mushrooms/crimini/297.jpg
# datasets/mushrooms/crimini/326.jpg
# datasets/mushrooms/crimini/389.jpg
# datasets/mushrooms/crimini/275.jpg
# datasets/mushrooms/crimini/579.jpg
# datasets/mushrooms/crimini/448.jpg
# datasets/mushrooms/crimini/472.jpg
# datasets/mushrooms/crimini/37.jpg
# datasets/mushrooms/crimini/255.jpg
# datasets/mushrooms/crimini/66.jpg
# datasets/mushrooms/crimini/335.jpg
# datasets/mushrooms/crimini/560.jpg
# datasets/mushrooms/crimini/76.jpg
# datasets/mushrooms/crimini/396.jpg
# datasets/mushrooms/crimini/316.jpg
# datasets/mushrooms/crimini/241.jpg
# datasets/mushrooms/crimini/499.jpg
# datasets/mushrooms/crimini/98.jpg
# datasets/mushrooms/crimini/240.jpg
# datasets/mushrooms/crimini/147.jpg
# datasets/mushrooms/crimini/467.jpg
# datasets/mushrooms/crimini/340.jpg
# datasets/mushrooms/crimini/55.jpg
# datasets/mushrooms/crimini/512.jpg
# datasets/mushrooms/crimini/523.jpg
# datasets/mushrooms/crimini/278.jpg
# datasets/mushrooms/crimini/505.jpg
# datasets/mushrooms/crimini/232.jpg
# datasets/mushrooms/crimini/143.jpg
# datasets/mushrooms/crimini/265.jpg
# datasets/mushrooms/crimini/400.jpg
# datasets/mushrooms/crimini/388.jpg
# datasets/mushrooms/crimini/136.jpg
# datasets/mushrooms/crimini/70.jpg
# datasets/mushrooms/crimini/217.jpg
# datasets/mushrooms/crimini/367.jpg
# datasets/mushrooms/crimini/24.jpg
# datasets/mushrooms/crimini/277.jpg
# datasets/mushrooms/crimini/172.jpg
# datasets/mushrooms/crimini/109.jpg
# datasets/mushrooms/crimini/323.jpg
# datasets/mushrooms/crimini/42.jpg
# datasets/mushrooms/crimini/177.jpg
# datasets/mushrooms/crimini/312.jpg
# datasets/mushrooms/crimini/82.jpg
# datasets/mushrooms/crimini/123.jpg
# datasets/mushrooms/crimini/170.jpg
# datasets/mushrooms/crimini/459.jpg
# datasets/mushrooms/crimini/444.jpg
# datasets/mushrooms/crimini/317.jpg
# datasets/mushrooms/crimini/61.jpg
# datasets/mushrooms/crimini/338.jpg
# datasets/mushrooms/crimini/314.jpg
# datasets/mushrooms/crimini/228.jpg
# datasets/mushrooms/crimini/547.jpg
# datasets/mushrooms/crimini/562.jpg
# datasets/mushrooms/crimini/309.jpg
# datasets/mushrooms/crimini/193.jpg
# datasets/mushrooms/crimini/220.jpg
# datasets/mushrooms/crimini/92.jpg
# datasets/mushrooms/crimini/204.jpg
# datasets/mushrooms/crimini/81.jpg
# datasets/mushrooms/crimini/227.jpg
# datasets/mushrooms/crimini/49.jpg
# datasets/mushrooms/crimini/504.jpg
# datasets/mushrooms/crimini/319.jpg
# datasets/mushrooms/crimini/590.jpg
# datasets/mushrooms/crimini/301.jpg
# datasets/mushrooms/crimini/339.jpg
# datasets/mushrooms/crimini/293.jpg
# datasets/mushrooms/crimini/361.jpg
# datasets/mushrooms/crimini/131.jpg
# datasets/mushrooms/crimini/294.jpg
# datasets/mushrooms/crimini/44.jpg
# datasets/mushrooms/crimini/160.jpg
# datasets/mushrooms/crimini/324.jpg
# datasets/mushrooms/crimini/145.jpg
# datasets/mushrooms/crimini/163.jpg
# datasets/mushrooms/crimini/54.jpg
# datasets/mushrooms/crimini/576.jpg
# datasets/mushrooms/crimini/368.jpg
# datasets/mushrooms/crimini/62.jpg
# datasets/mushrooms/crimini/127.jpg
# datasets/mushrooms/crimini/281.jpg
# datasets/mushrooms/crimini/474.jpg
# datasets/mushrooms/crimini/564.jpg
# datasets/mushrooms/crimini/491.jpg
# datasets/mushrooms/crimini/36.jpg
# datasets/mushrooms/crimini/359.jpg
# datasets/mushrooms/crimini/493.jpg
# datasets/mushrooms/crimini/568.jpg
# datasets/mushrooms/crimini/426.jpg
# datasets/mushrooms/crimini/104.jpg
# datasets/mushrooms/crimini/429.jpg
# datasets/mushrooms/crimini/271.jpg
# datasets/mushrooms/crimini/89.jpg
# datasets/mushrooms/crimini/158.jpg
# datasets/mushrooms/crimini/369.jpg
# datasets/mushrooms/crimini/69.jpg
# datasets/mushrooms/crimini/528.jpg
# datasets/mushrooms/crimini/411.jpg
# datasets/mushrooms/crimini/218.jpg
# datasets/mushrooms/crimini/373.jpg
# datasets/mushrooms/crimini/441.jpg
# datasets/mushrooms/crimini/199.jpg
# datasets/mushrooms/crimini/259.jpg
# datasets/mushrooms/crimini/406.jpg
# datasets/mushrooms/crimini/543.jpg
# datasets/mushrooms/crimini/376.jpg
# datasets/mushrooms/crimini/161.jpg
# datasets/mushrooms/crimini/247.jpg
# datasets/mushrooms/crimini/77.jpg
# datasets/mushrooms/crimini/352.jpg
# datasets/mushrooms/crimini/90.jpg
# datasets/mushrooms/crimini/458.jpg
# datasets/mushrooms/crimini/125.jpg
# datasets/mushrooms/crimini/363.jpg
# datasets/mushrooms/crimini/372.jpg
# datasets/mushrooms/crimini/384.jpg
# datasets/mushrooms/crimini/570.jpg
# datasets/mushrooms/crimini/284.jpg
# datasets/mushrooms/crimini/525.jpg
# datasets/mushrooms/crimini/468.jpg
# datasets/mushrooms/crimini/424.jpg
# datasets/mushrooms/crimini/209.jpg
# datasets/mushrooms/crimini/465.jpg
# datasets/mushrooms/crimini/237.jpg
# datasets/mushrooms/crimini/188.jpg
# datasets/mushrooms/crimini/133.jpg
# datasets/mushrooms/crimini/315.jpg
# datasets/mushrooms/crimini/567.jpg
# datasets/mushrooms/crimini/559.jpg
# datasets/mushrooms/crimini/434.jpg
# datasets/mushrooms/crimini/211.jpg
# datasets/mushrooms/crimini/386.jpg
# datasets/mushrooms/crimini/65.jpg
# datasets/mushrooms/crimini/243.jpg
# datasets/mushrooms/crimini/142.jpg
# datasets/mushrooms/crimini/450.jpg
# datasets/mushrooms/crimini/279.jpg
# datasets/mushrooms/crimini/469.jpg
# datasets/mushrooms/crimini/419.jpg
# datasets/mushrooms/crimini/473.jpg
# datasets/mushrooms/crimini/18.jpg
# datasets/mushrooms/crimini/258.jpg
# datasets/mushrooms/crimini/416.jpg
# datasets/mushrooms/crimini/254.jpg
# datasets/mushrooms/crimini/360.jpg
# datasets/mushrooms/crimini/154.jpg
# datasets/mushrooms/crimini/506.jpg
# datasets/mushrooms/crimini/106.jpg
# datasets/mushrooms/crimini/325.jpg
# datasets/mushrooms/crimini/19.jpg
# datasets/mushrooms/crimini/93.jpg
# datasets/mushrooms/crimini/23.jpg
# datasets/mushrooms/crimini/196.jpg
# datasets/mushrooms/crimini/39.jpg
# datasets/mushrooms/crimini/194.jpg
# datasets/mushrooms/crimini/408.jpg
# datasets/mushrooms/crimini/446.jpg
# datasets/mushrooms/crimini/262.jpg
# datasets/mushrooms/crimini/252.jpg
# datasets/mushrooms/crimini/253.jpg
# datasets/mushrooms/crimini/518.jpg
# datasets/mushrooms/crimini/56.jpg
# datasets/mushrooms/crimini/509.jpg
# datasets/mushrooms/crimini/130.jpg
# datasets/mushrooms/crimini/179.jpg
# datasets/mushrooms/crimini/496.jpg
# datasets/mushrooms/crimini/370.jpg
# datasets/mushrooms/crimini/295.jpg
# datasets/mushrooms/crimini/102.jpg
# datasets/mushrooms/crimini/526.jpg
# datasets/mushrooms/crimini/498.jpg
# datasets/mushrooms/crimini/510.jpg
# datasets/mushrooms/crimini/155.jpg
# datasets/mushrooms/crimini/478.jpg
# datasets/mushrooms/crimini/63.jpg
# datasets/mushrooms/crimini/14.jpg
# datasets/mushrooms/crimini/332.jpg
# datasets/mushrooms/crimini/379.jpg
# datasets/mushrooms/crimini/427.jpg
# datasets/mushrooms/crimini/303.jpg
# datasets/mushrooms/crimini/354.jpg
# datasets/mushrooms/crimini/189.jpg
# datasets/mushrooms/crimini/333.jpg
# datasets/mushrooms/crimini/185.jpg
# datasets/mushrooms/crimini/451.jpg
# datasets/mushrooms/crimini/511.jpg
# datasets/mushrooms/crimini/113.jpg
# datasets/mushrooms/crimini/595.jpg
# datasets/mushrooms/crimini/378.jpg
# datasets/mushrooms/crimini/492.jpg
# datasets/mushrooms/crimini/471.jpg
# datasets/mushrooms/crimini/58.jpg
# datasets/mushrooms/crimini/182.jpg
# datasets/mushrooms/crimini/357.jpg
# datasets/mushrooms/crimini/190.jpg
# datasets/mushrooms/crimini/540.jpg
# datasets/mushrooms/crimini/219.jpg
# datasets/mushrooms/crimini/414.jpg
# datasets/mushrooms/crimini/342.jpg
# datasets/mushrooms/crimini/555.jpg
# datasets/mushrooms/crimini/460.jpg
# datasets/mushrooms/crimini/311.jpg
# datasets/mushrooms/crimini/51.jpg
# datasets/mushrooms/crimini/327.jpg
# datasets/mushrooms/crimini/347.jpg
# datasets/mushrooms/crimini/462.jpg
# datasets/mushrooms/crimini/483.jpg
# datasets/mushrooms/crimini/235.jpg
# datasets/mushrooms/crimini/464.jpg
# datasets/mushrooms/crimini/169.jpg
# datasets/mushrooms/crimini/28.jpg
# datasets/mushrooms/crimini/149.jpg
# datasets/mushrooms/crimini/343.jpg
# datasets/mushrooms/crimini/572.jpg
# datasets/mushrooms/crimini/139.jpg
# datasets/mushrooms/crimini/248.jpg
# datasets/mushrooms/crimini/524.jpg
# datasets/mushrooms/crimini/470.jpg
# datasets/mushrooms/crimini/150.jpg
# datasets/mushrooms/crimini/176.jpg
# datasets/mushrooms/crimini/486.jpg
# datasets/mushrooms/crimini/289.jpg
# datasets/mushrooms/crimini/206.jpg
# datasets/mushrooms/crimini/138.jpg
# datasets/mushrooms/crimini/356.jpg
# datasets/mushrooms/crimini/571.jpg
# datasets/mushrooms/crimini/214.jpg
# datasets/mushrooms/crimini/578.jpg
# datasets/mushrooms/crimini/250.jpg
# datasets/mushrooms/crimini/599.jpg
# datasets/mushrooms/crimini/503.jpg
# datasets/mushrooms/crimini/72.jpg
# datasets/mushrooms/crimini/310.jpg
# datasets/mushrooms/crimini/198.jpg
# datasets/mushrooms/crimini/286.jpg
# datasets/mushrooms/crimini/171.jpg
# datasets/mushrooms/crimini/519.jpg
# datasets/mushrooms/crimini/60.jpg
# datasets/mushrooms/crimini/112.jpg
# datasets/mushrooms/crimini/587.jpg
# datasets/mushrooms/crimini/447.jpg
# datasets/mushrooms/crimini/224.jpg
# datasets/mushrooms/crimini/167.jpg
# datasets/mushrooms/crimini/534.jpg
# datasets/mushrooms/crimini/282.jpg
# datasets/mushrooms/crimini/375.jpg
# datasets/mushrooms/crimini/353.jpg
# datasets/mushrooms/crimini/390.jpg
# datasets/mushrooms/crimini/87.jpg
# datasets/mushrooms/crimini/141.jpg
# datasets/mushrooms/crimini/47.jpg
# datasets/mushrooms/crimini/445.jpg
# datasets/mushrooms/crimini/589.jpg
# datasets/mushrooms/crimini/212.jpg
# datasets/mushrooms/crimini/148.jpg
# datasets/mushrooms/crimini/84.jpg
# datasets/mushrooms/crimini/573.jpg
# datasets/mushrooms/crimini/22.jpg
# datasets/mushrooms/crimini/21.jpg
# datasets/mushrooms/crimini/397.jpg
# datasets/mushrooms/crimini/74.jpg
# datasets/mushrooms/crimini/229.jpg
# datasets/mushrooms/crimini/68.jpg
# datasets/mushrooms/crimini/487.jpg
# datasets/mushrooms/crimini/88.jpg
# datasets/mushrooms/crimini/43.jpg
# datasets/mushrooms/crimini/344.jpg
# datasets/mushrooms/crimini/48.jpg
# datasets/mushrooms/crimini/514.jpg
# datasets/mushrooms/crimini/152.jpg
# datasets/mushrooms/crimini/96.jpg
# datasets/mushrooms/crimini/12.jpg
# datasets/mushrooms/crimini/598.jpg
# datasets/mushrooms/crimini/108.jpg
# datasets/mushrooms/crimini/418.jpg
# datasets/mushrooms/crimini/121.jpg
# datasets/mushrooms/crimini/415.jpg
# datasets/mushrooms/crimini/475.jpg
# datasets/mushrooms/crimini/382.jpg
# datasets/mushrooms/crimini/453.jpg
# datasets/mushrooms/crimini/57.jpg
# datasets/mushrooms/crimini/166.jpg
# datasets/mushrooms/crimini/249.jpg
# datasets/mushrooms/crimini/246.jpg
# datasets/mushrooms/crimini/480.jpg
# datasets/mushrooms/crimini/438.jpg
# datasets/mushrooms/crimini/78.jpg
# datasets/mushrooms/crimini/307.jpg
# datasets/mushrooms/crimini/300.jpg
# datasets/mushrooms/crimini/322.jpg
# datasets/mushrooms/crimini/29.jpg
# datasets/mushrooms/crimini/439.jpg
# datasets/mushrooms/crimini/549.jpg
# datasets/mushrooms/crimini/394.jpg
# datasets/mushrooms/crimini/351.jpg
# datasets/mushrooms/crimini/244.jpg
# datasets/mushrooms/crimini/402.jpg
# datasets/mushrooms/crimini/137.jpg
# datasets/mushrooms/crimini/346.jpg
# datasets/mushrooms/crimini/215.jpg
# datasets/mushrooms/crimini/449.jpg
# datasets/mushrooms/crimini/410.jpg
# datasets/mushrooms/crimini/544.jpg
# datasets/mushrooms/crimini/162.jpg
# datasets/mushrooms/crimini/539.jpg
# datasets/mushrooms/crimini/304.jpg
# datasets/mushrooms/crimini/436.jpg
# datasets/mushrooms/crimini/407.jpg
# datasets/mushrooms/crimini/330.jpg
# datasets/mushrooms/crimini/151.jpg
# datasets/mushrooms/crimini/156.jpg
# datasets/mushrooms/crimini/320.jpg
# datasets/mushrooms/crimini/541.jpg
# datasets/mushrooms/crimini/432.jpg
# datasets/mushrooms/crimini/267.jpg
# datasets/mushrooms/crimini/118.jpg
# datasets/mushrooms/crimini/531.jpg
# datasets/mushrooms/crimini/208.jpg
# datasets/mushrooms/crimini/99.jpg
# datasets/mushrooms/crimini/257.jpg
# datasets/mushrooms/crimini/501.jpg
# datasets/mushrooms/crimini/174.jpg
# datasets/mushrooms/crimini/398.jpg
# datasets/mushrooms/crimini/175.jpg
# datasets/mushrooms/crimini/302.jpg
# datasets/mushrooms/crimini/551.jpg
# datasets/mushrooms/crimini/10.jpg
# datasets/mushrooms/crimini/234.jpg
# datasets/mushrooms/crimini/385.jpg
# datasets/mushrooms/crimini/507.jpg
# datasets/mushrooms/crimini/5.jpg
# datasets/mushrooms/crimini/263.jpg
# datasets/mushrooms/crimini/306.jpg
# datasets/mushrooms/crimini/298.jpg
# datasets/mushrooms/crimini/53.jpg
# datasets/mushrooms/crimini/0.jpg
# datasets/mushrooms/crimini/233.jpg
# datasets/mushrooms/crimini/466.jpg
# datasets/mushrooms/crimini/197.jpg
# datasets/mushrooms/crimini/437.jpg
# datasets/mushrooms/crimini/45.jpg
# datasets/mushrooms/crimini/377.jpg
# datasets/mushrooms/crimini/443.jpg
# datasets/mushrooms/crimini/16.jpg
# datasets/mushrooms/crimini/488.jpg
# datasets/mushrooms/crimini/583.jpg
# datasets/mushrooms/crimini/581.jpg
# datasets/mushrooms/crimini/225.jpg
# datasets/mushrooms/crimini/484.jpg
# datasets/mushrooms/crimini/513.jpg
# datasets/mushrooms/crimini/181.jpg
# datasets/mushrooms/crimini/207.jpg
# datasets/mushrooms/crimini/495.jpg
# datasets/mushrooms/crimini/30.jpg
# datasets/mushrooms/crimini/582.jpg
# datasets/mushrooms/crimini/521.jpg
# datasets/mushrooms/crimini/200.jpg
# datasets/mushrooms/crimini/186.jpg
# datasets/mushrooms/crimini/230.jpg
# datasets/mushrooms/crimini/565.jpg
# datasets/mushrooms/crimini/405.jpg
# datasets/mushrooms/crimini/552.jpg
# datasets/mushrooms/crimini/201.jpg
# datasets/mushrooms/crimini/409.jpg
# datasets/mushrooms/crimini/435.jpg
# datasets/mushrooms/crimini/362.jpg
# datasets/mushrooms/crimini/502.jpg
# datasets/mushrooms/crimini/80.jpg
# datasets/mushrooms/crimini/433.jpg
# datasets/mushrooms/crimini/364.jpg
# datasets/mushrooms/crimini/355.jpg
# datasets/mushrooms/crimini/530.jpg
# datasets/mushrooms/crimini/34.jpg
# datasets/mushrooms/crimini/73.jpg
# datasets/mushrooms/crimini/350.jpg
# datasets/mushrooms/crimini/40.jpg
# datasets/mushrooms/crimini/165.jpg
# datasets/mushrooms/crimini/67.jpg
# datasets/mushrooms/crimini/280.jpg
# datasets/mushrooms/crimini/31.jpg
# datasets/mushrooms/crimini/403.jpg
# datasets/mushrooms/crimini/238.jpg
# datasets/mushrooms/crimini/563.jpg
# datasets/mushrooms/crimini/239.jpg
# datasets/mushrooms/crimini/420.jpg
# datasets/mushrooms/crimini/110.jpg
# datasets/mushrooms/crimini/135.jpg
# datasets/mushrooms/crimini/430.jpg
# datasets/mushrooms/crimini/348.jpg
# datasets/mushrooms/crimini/27.jpg
# datasets/mushrooms/crimini/291.jpg
# datasets/mushrooms/crimini/203.jpg
# datasets/mushrooms/crimini/358.jpg
# datasets/mushrooms/crimini/535.jpg
# datasets/mushrooms/crimini/482.jpg
# datasets/mushrooms/crimini/111.jpg
# datasets/mushrooms/crimini/231.jpg
# datasets/mushrooms/crimini/122.jpg
# datasets/mushrooms/crimini/9.jpg
# datasets/mushrooms/crimini/554.jpg
# datasets/mushrooms/crimini/95.jpg
# datasets/mushrooms/crimini/187.jpg
# datasets/mushrooms/crimini/374.jpg
# datasets/mushrooms/crimini/566.jpg
# mean: [146.99367095 132.88599115 115.4490384 ]
# stdev: [77.331301   76.97771813 82.08600301]
# Execution time (mins) 0.8575249274571737
